# %%
import pandas
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('max_columns', None)
FILE_NAME = "lawsuit_k_supp2"

df_pydl = pandas.read_csv("lawsuit/save/"+FILE_NAME+"_relab.csv")
df_pydl2 = pandas.read_csv("lawsuit2/save/"+FILE_NAME+".csv")
df_pydl3 = pandas.read_csv("lawsuit3/save/"+FILE_NAME+".csv")
df_sklearn = pandas.read_csv("lawsuit/save/"+FILE_NAME+"_relab_sklearn.csv")

# %%
df_pydl
# Out:
#            k  depth  random_state    clf.error_  clf.accuracy_  accuracy_pred  \
# 0          0      1             1     51.000000       0.755981       0.755981
# 1          0      1             3     48.000000       0.770335       0.770335
# 2          0      1             5     49.000000       0.765550       0.765550
# 3          0      1             7     51.000000       0.755981       0.755981
# 4          0      1             9     54.000000       0.741627       0.741627
# ...      ...    ...           ...           ...            ...            ...
# 3460  100000      7            89  31923.021484    -151.741730       0.885167
# 3461  100000      7            93  29877.371094    -141.953934       0.894737
# 3462  100000      7            95  35396.804688    -168.362701       0.909091
# 3463  100000      7            97  34281.562500    -163.026611       0.913876
# 3464  100000      7            99  36054.304688    -171.508636       0.918660
#
#       accuracy_test  sum_misclassified_train  discrimination_train  \
# 0          0.730769                       51              0.325619
# 1          0.673077                       48              0.304364
# 2          0.692308                       49              0.324563
# 3          0.730769                       51              0.290782
# 4          0.788462                       54              0.316116
# ...             ...                      ...                   ...
# 3460       0.903846                       24              0.318990
# 3461       0.923077                       22              0.298554
# 3462       0.846154                       19              0.353778
# 3463       0.807692                       18              0.342636
# 3464       0.826923                       17              0.360373
#
#       sum_discrimination_additive_train  \
# 0                              0.325619
# 1                              0.304364
# 2                              0.324563
# 3                              0.290782
# 4                              0.316116
# ...                                 ...
# 3460                           0.318990
# 3461                           0.298554
# 3462                           0.353778
# 3463                           0.342636
# 3464                           0.360373
#
#       sum_discrimination_additive_train_abs  discrimination_train_pred  \
# 0                                  0.325619                   0.156476
# 1                                  0.304364                   0.234535
# 2                                  0.324563                   0.179566
# 3                                  0.290782                   0.185791
# 4                                  0.316116                   0.144628
# ...                                     ...                        ...
# 3460                               0.318990                   0.281985
# 3461                               0.298554                   0.227273
# 3462                               0.353778                   0.273318
# 3463                               0.342636                   0.242636
# 3464                               0.360373                   0.286508
#
#       sum_discrimination_additive_train_pred  \
# 0                                   0.156476
# 1                                   0.234535
# 2                                   0.179566
# 3                                   0.185791
# 4                                   0.144628
# ...                                      ...
# 3460                                0.281985
# 3461                                0.227273
# 3462                                0.273318
# 3463                                0.242636
# 3464                                0.286508
#
#       sum_discrimination_additive_train_pred_abs  discrimination_test  \
# 0                                       0.156476             0.266667
# 1                                       0.234535            -0.046083
# 2                                       0.179566             0.172619
# 3                                       0.185791             0.137931
# 4                                       0.144628             0.297386
# ...                                          ...                  ...
# 3460                                    0.281985             0.151424
# 3461                                    0.237603             0.421569
# 3462                                    0.273318             0.161085
# 3463                                    0.242636             0.269231
# 3464                                    0.286508             0.063796
#
#       sum_discrimination_additive_test_pred  \
# 0                                  0.266667
# 1                                 -0.046083
# 2                                  0.172619
# 3                                  0.137931
# 4                                  0.297386
# ...                                     ...
# 3460                               0.151424
# 3461                               0.421569
# 3462                               0.161085
# 3463                               0.269231
# 3464                               0.063796
#
#       sum_discrimination_additive_test_pred_abs  duration  min_supp  \
# 0                                      0.266667  0.031886         2
# 1                                      0.046083  0.027164         2
# 2                                      0.172619  0.027535         2
# 3                                      0.137931  0.014580         2
# 4                                      0.297386  0.033851         2
# ...                                         ...       ...       ...
# 3460                                   0.343328  4.257717         2
# 3461                                   0.421569  4.131410         2
# 3462                                   0.263158  4.363840         2
# 3463                                   0.269231  4.132237         2
# 3464                                   0.178628  4.731878         2
#
#                                               clf.tree_  accuracy_relab_1  \
# 0     {'feat': 10, 'left': {'value': 1, 'error': 0.0...           0.60287
# 1     {'feat': 10, 'left': {'value': 1, 'error': 0.0...           0.60765
# 2     {'feat': 10, 'left': {'value': 1, 'error': 0.0...           0.60765
# 3     {'feat': 10, 'left': {'value': 1, 'error': 0.0...           0.58373
# 4     {'feat': 10, 'left': {'value': 1, 'error': 0.0...           0.61244
# ...                                                 ...               ...
# 3460  {'feat': 1, 'left': {'feat': 2, 'left': {'feat...           0.88038
# 3461  {'feat': 5, 'left': {'feat': 0, 'left': {'valu...           0.88995
# 3462  {'feat': 0, 'left': {'feat': 4, 'left': {'feat...           0.90430
# 3463  {'feat': 1, 'left': {'feat': 2, 'left': {'feat...           0.88516
# 3464  {'feat': 1, 'left': {'feat': 4, 'left': {'feat...           0.88038
#
#       discrimination_relab_1  discrimination_relab_abs_1  \
# 0                    0.00000                     0.00000
# 1                    0.00000                     0.00000
# 2                    0.00000                     0.00000
# 3                    0.00000                     0.00000
# 4                    0.00000                     0.00000
# ...                      ...                         ...
# 3460                 0.24230                     0.24230
# 3461                 0.20351                     0.26136
# 3462                 0.24872                     0.24872
# 3463                 0.16763                     0.31763
# 3464                 0.19455                     0.37846
#
#       accuracy_relab_test_1  discrimination_relab_test_1  \
# 0                   0.57692                     0.000000
# 1                   0.55769                     0.000000
# 2                   0.55769                     0.000000
# 3                   0.65384                     0.000000
# 4                   0.53846                     0.000000
# ...                     ...                          ...
# 3460                0.88461                     0.194903
# 3461                0.88461                     0.480392
# 3462                0.84615                     0.161085
# 3463                0.78846                     0.230769
# 3464                0.80769                     0.094099
#
#       discrimination_relab_test_abs_1  accuracy_relab_2  \
# 0                            0.000000           0.24401
# 1                            0.000000           0.22966
# 2                            0.000000           0.23444
# 3                            0.000000           0.24401
# 4                            0.000000           0.25837
# ...                               ...               ...
# 3460                         0.299850           0.87559
# 3461                         0.480392           0.88038
# 3462                         0.263158           0.89952
# 3463                         0.307692           0.87081
# 3464                         0.208931           0.86602
#
#       discrimination_relab_2  discrimination_relab_abs_2  \
# 0                   -0.15648                     0.15647
# 1                   -0.23454                     0.23453
# 2                   -0.17957                     0.17956
# 3                   -0.18580                     0.18579
# 4                   -0.14463                     0.14462
# ...                      ...                         ...
# 3460                 0.21849                     0.21849
# 3461                 0.18078                     0.28409
# 3462                 0.23393                     0.26351
# 3463                 0.13013                     0.35513
# 3464                 0.16996                     0.35387
#
#       accuracy_relab_test_2  discrimination_relab_test_2  \
# 0                   0.26923                    -0.266667
# 1                   0.32692                     0.046083
# 2                   0.30769                    -0.172619
# 3                   0.26923                    -0.137931
# 4                   0.21153                    -0.297386
# ...                     ...                          ...
# 3460                0.88461                     0.194903
# 3461                0.88461                     0.480392
# 3462                0.78846                     0.146730
# 3463                0.78846                     0.230769
# 3464                0.78846                     0.063796
#
#       discrimination_relab_test_abs_2  accuracy_relab_3  \
# 0                            0.266667           0.24401
# 1                            0.046083           0.22966
# 2                            0.172619           0.23444
# 3                            0.137931           0.24401
# 4                            0.297386           0.25837
# ...                               ...               ...
# 3460                         0.299850           0.84210
# 3461                         0.480392           0.86602
# 3462                         0.277512           0.88995
# 3463                         0.307692           0.81339
# 3464                         0.178628           0.85645
#
#       discrimination_relab_3  discrimination_relab_abs_3  \
# 0                   -0.15648                     0.15647
# 1                   -0.23454                     0.23453
# 2                   -0.17957                     0.17956
# 3                   -0.18580                     0.18579
# 4                   -0.14463                     0.14462
# ...                      ...                         ...
# 3460                 0.13415                     0.30283
# 3461                 0.15599                     0.25929
# 3462                 0.21094                     0.28650
# 3463                 0.00038                     0.48488
# 3464                 0.15357                     0.33747
#
#       accuracy_relab_test_3  discrimination_relab_test_3  \
# 0                   0.26923                    -0.266667
# 1                   0.32692                     0.046083
# 2                   0.30769                    -0.172619
# 3                   0.26923                    -0.137931
# 4                   0.21153                    -0.297386
# ...                     ...                          ...
# 3460                0.88461                     0.194903
# 3461                0.88461                     0.480392
# 3462                0.78846                     0.146730
# 3463                0.75000                     0.153846
# 3464                0.76923                     0.033493
#
#       discrimination_relab_test_abs_3  accuracy_relab_0.0  \
# 0                            0.266667             0.60287
# 1                            0.046083             0.60765
# 2                            0.172619             0.60765
# 3                            0.137931             0.58373
# 4                            0.297386             0.61244
# ...                               ...                 ...
# 3460                         0.299850             0.77511
# 3461                         0.480392             0.70813
# 3462                         0.277512             0.77511
# 3463                         0.384615             0.80382
# 3464                         0.148325             0.75119
#
#       discrimination_relab_0.0  discrimination_relab_abs_0.0  \
# 0                      0.00000                       0.00000
# 1                      0.00000                       0.00000
# 2                      0.00000                       0.00000
# 3                      0.00000                       0.00000
# 4                      0.00000                       0.00000
# ...                        ...                           ...
# 3460                  -0.01454                       0.45152
# 3461                  -0.06199                       0.47727
# 3462                  -0.00914                       0.47380
# 3463                  -0.01512                       0.46937
# 3464                  -0.01395                       0.47220
#
#       accuracy_relab_test_0.0  discrimination_relab_test_0.0  \
# 0                     0.57692                       0.000000
# 1                     0.55769                       0.000000
# 2                     0.55769                       0.000000
# 3                     0.65384                       0.000000
# 4                     0.53846                       0.000000
# ...                       ...                            ...
# 3460                  0.80769                       0.176912
# 3461                  0.76923                       0.401961
# 3462                  0.63461                      -0.070175
# 3463                  0.73076                       0.115385
# 3464                  0.71153                       0.041467
#
#       discrimination_relab_test_abs_0.0  accuracy_relab_0.05  \
# 0                              0.000000              0.60287
# 1                              0.000000              0.60765
# 2                              0.000000              0.60765
# 3                              0.000000              0.58373
# 4                              0.000000              0.61244
# ...                                 ...                  ...
# 3460                           0.368816              0.77511
# 3461                           0.676471              0.70813
# 3462                           0.510367              0.80861
# 3463                           0.346154              0.81339
# 3464                           0.156300              0.75119
#
#       discrimination_relab_0.05  discrimination_relab_abs_0.05  \
# 0                       0.00000                        0.00000
# 1                       0.00000                        0.00000
# 2                       0.00000                        0.00000
# 3                       0.00000                        0.00000
# 4                       0.00000                        0.00000
# ...                         ...                            ...
# 3460                   -0.01454                        0.45152
# 3461                   -0.06199                        0.47727
# 3462                    0.04183                        0.42283
# 3463                    0.00038                        0.48488
# 3464                   -0.01395                        0.47220
#
#       accuracy_relab_test_0.05  discrimination_relab_test_0.05  \
# 0                      0.57692                        0.000000
# 1                      0.55769                        0.000000
# 2                      0.55769                        0.000000
# 3                      0.65384                        0.000000
# 4                      0.53846                        0.000000
# ...                        ...                             ...
# 3460                   0.80769                        0.176912
# 3461                   0.76923                        0.401961
# 3462                   0.63461                       -0.086124
# 3463                   0.75000                        0.153846
# 3464                   0.71153                        0.041467
#
#       discrimination_relab_test_abs_0.05  accuracy_relab_0.1  \
# 0                               0.000000             0.60287
# 1                               0.000000             0.60765
# 2                               0.000000             0.60765
# 3                               0.000000             0.58373
# 4                               0.000000             0.61244
# ...                                  ...                 ...
# 3460                            0.368816             0.82296
# 3461                            0.676471             0.81339
# 3462                            0.449761             0.81818
# 3463                            0.384615             0.81339
# 3464                            0.156300             0.79425
#
#       discrimination_relab_0.1  discrimination_relab_abs_0.1  \
# 0                      0.00000                       0.00000
# 1                      0.00000                       0.00000
# 2                      0.00000                       0.00000
# 3                      0.00000                       0.00000
# 4                      0.00000                       0.00000
# ...                        ...                           ...
# 3460                   0.08596                       0.35102
# 3461                   0.07024                       0.34504
# 3462                   0.05822                       0.43923
# 3463                   0.00038                       0.48488
# 3464                   0.05012                       0.40814
#
#       accuracy_relab_test_0.1  discrimination_relab_test_0.1  \
# 0                     0.57692                       0.000000
# 1                     0.55769                       0.000000
# 2                     0.55769                       0.000000
# 3                     0.65384                       0.000000
# 4                     0.53846                       0.000000
# ...                       ...                            ...
# 3460                  0.82692                       0.220390
# 3461                  0.84615                       0.539216
# 3462                  0.65384                      -0.055821
# 3463                  0.75000                       0.153846
# 3464                  0.76923                       0.033493
#
#       discrimination_relab_test_abs_0.1  accuracy_relab_0.15  \
# 0                              0.000000              0.60287
# 1                              0.000000              0.60765
# 2                              0.000000              0.60765
# 3                              0.000000              0.58373
# 4                              0.000000              0.74162
# ...                                 ...                  ...
# 3460                           0.325337              0.84210
# 3461                           0.539216              0.81339
# 3462                           0.480064              0.85167
# 3463                           0.384615              0.87081
# 3464                           0.148325              0.84688
#
#       discrimination_relab_0.15  discrimination_relab_abs_0.15  \
# 0                       0.00000                        0.00000
# 1                       0.00000                        0.00000
# 2                       0.00000                        0.00000
# 3                       0.00000                        0.00000
# 4                       0.14462                        0.14462
# ...                         ...                            ...
# 3460                    0.13415                        0.30283
# 3461                    0.07024                        0.34504
# 3462                    0.11899                        0.37846
# 3463                    0.13013                        0.35513
# 3464                    0.13717                        0.32108
#
#       accuracy_relab_test_0.15  discrimination_relab_test_0.15  \
# 0                      0.57692                        0.000000
# 1                      0.55769                        0.000000
# 2                      0.55769                        0.000000
# 3                      0.65384                        0.000000
# 4                      0.78846                        0.297386
# ...                        ...                             ...
# 3460                   0.88461                        0.194903
# 3461                   0.84615                        0.539216
# 3462                   0.75000                        0.041467
# 3463                   0.78846                        0.230769
# 3464                   0.76923                        0.033493
#
#       discrimination_relab_test_abs_0.15  accuracy_relab_0.2  \
# 0                               0.000000             0.75598
# 1                               0.000000             0.60765
# 2                               0.000000             0.76555
# 3                               0.000000             0.75598
# 4                               0.297386             0.74162
# ...                                  ...                 ...
# 3460                            0.299850             0.84210
# 3461                            0.539216             0.88038
# 3462                            0.382775             0.87559
# 3463                            0.307692             0.88516
# 3464                            0.148325             0.88038
#
#       discrimination_relab_0.2  discrimination_relab_abs_0.2  \
# 0                      0.15647                       0.15647
# 1                      0.00000                       0.00000
# 2                      0.17956                       0.17956
# 3                      0.18579                       0.18579
# 4                      0.14462                       0.14462
# ...                        ...                           ...
# 3460                   0.13415                       0.30283
# 3461                   0.18078                       0.28409
# 3462                   0.17646                       0.32099
# 3463                   0.16763                       0.31763
# 3464                   0.19455                       0.37846
#
#       accuracy_relab_test_0.2  discrimination_relab_test_0.2  \
# 0                     0.73076                       0.266667
# 1                     0.55769                       0.000000
# 2                     0.69230                       0.172619
# 3                     0.73076                       0.137931
# 4                     0.78846                       0.297386
# ...                       ...                            ...
# 3460                  0.88461                       0.194903
# 3461                  0.88461                       0.480392
# 3462                  0.75000                       0.041467
# 3463                  0.78846                       0.230769
# 3464                  0.80769                       0.094099
#
#       discrimination_relab_test_abs_0.2  accuracy_relab_0.25  \
# 0                              0.266667              0.75598
# 1                              0.000000              0.77033
# 2                              0.172619              0.76555
# 3                              0.137931              0.75598
# 4                              0.297386              0.74162
# ...                                 ...                  ...
# 3460                           0.299850              0.88038
# 3461                           0.480392              0.89473
# 3462                           0.382775              0.90430
# 3463                           0.307692              0.91387
# 3464                           0.208931              0.88038
#
#       discrimination_relab_0.25  discrimination_relab_abs_0.25  \
# 0                       0.15647                        0.15647
# 1                       0.23453                        0.23453
# 2                       0.17956                        0.17956
# 3                       0.18579                        0.18579
# 4                       0.14462                        0.14462
# ...                         ...                            ...
# 3460                    0.24230                        0.24230
# 3461                    0.22727                        0.23760
# 3462                    0.24872                        0.24872
# 3463                    0.24263                        0.24263
# 3464                    0.19455                        0.37846
#
#       accuracy_relab_test_0.25  discrimination_relab_test_0.25  \
# 0                      0.73076                        0.266667
# 1                      0.67307                       -0.046083
# 2                      0.69230                        0.172619
# 3                      0.73076                        0.137931
# 4                      0.78846                        0.297386
# ...                        ...                             ...
# 3460                   0.88461                        0.194903
# 3461                   0.92307                        0.421569
# 3462                   0.84615                        0.161085
# 3463                   0.80769                        0.269231
# 3464                   0.80769                        0.094099
#
#       discrimination_relab_test_abs_0.25  accuracy_relab_0.3  \
# 0                               0.266667             0.75598
# 1                               0.046083             0.77033
# 2                               0.172619             0.76555
# 3                               0.137931             0.75598
# 4                               0.297386             0.74162
# ...                                  ...                 ...
# 3460                            0.299850             0.88516
# 3461                            0.421569             0.89473
# 3462                            0.263158             0.90909
# 3463                            0.269231             0.91387
# 3464                            0.208931             0.91866
#
#       discrimination_relab_0.3  discrimination_relab_abs_0.3  \
# 0                      0.15647                       0.15647
# 1                      0.23453                       0.23453
# 2                      0.17956                       0.17956
# 3                      0.18579                       0.18579
# 4                      0.14462                       0.14462
# ...                        ...                           ...
# 3460                   0.28198                       0.28198
# 3461                   0.22727                       0.23760
# 3462                   0.27331                       0.27331
# 3463                   0.24263                       0.24263
# 3464                   0.28650                       0.28650
#
#       accuracy_relab_test_0.3  discrimination_relab_test_0.3  \
# 0                     0.73076                       0.266667
# 1                     0.67307                      -0.046083
# 2                     0.69230                       0.172619
# 3                     0.73076                       0.137931
# 4                     0.78846                       0.297386
# ...                       ...                            ...
# 3460                  0.90384                       0.151424
# 3461                  0.92307                       0.421569
# 3462                  0.84615                       0.161085
# 3463                  0.80769                       0.269231
# 3464                  0.82692                       0.063796
#
#       discrimination_relab_test_abs_0.3
# 0                              0.266667
# 1                              0.046083
# 2                              0.172619
# 3                              0.137931
# 4                              0.297386
# ...                                 ...
# 3460                           0.343328
# 3461                           0.421569
# 3462                           0.263158
# 3463                           0.269231
# 3464                           0.178628
#
# [3465 rows x 80 columns]

# %%
df_pydl2
# Out:
#            k  depth  random_state    clf.error_  clf.accuracy_  accuracy_pred  \
# 0          0      1             1     51.000000       0.755981       0.755981
# 1          0      1             3     48.000000       0.770335       0.770335
# 2          0      1             5     49.000000       0.765550       0.765550
# 3          0      1             7     51.000000       0.755981       0.755981
# 4          0      1             9     54.000000       0.741627       0.741627
# ...      ...    ...           ...           ...            ...            ...
# 3460  100000      7            89   9635.744141     -45.104038       0.784689
# 3461  100000      7            93   8099.851074     -37.755268       0.799043
# 3462  100000      7            95  13012.431641     -61.260437       0.813397
# 3463  100000      7            97  13510.681641     -63.644409       0.846890
# 3464  100000      7            99  10401.249023     -48.766743       0.775120
#
#       accuracy_test  sum_misclassified_train  discrimination_train  \
# 0          0.730769                       51              0.325619
# 1          0.673077                       48              0.304364
# 2          0.692308                       49              0.324563
# 3          0.730769                       51              0.290782
# 4          0.788462                       54              0.316116
# ...             ...                      ...                   ...
# 3460       0.730769                       45              0.318990
# 3461       0.884615                       42              0.298554
# 3462       0.807692                       39              0.353778
# 3463       0.730769                       32              0.342636
# 3464       0.769231                       47              0.360373
#
#       sum_discrimination_additive_train  \
# 0                              0.325619
# 1                              0.304364
# 2                              0.324563
# 3                              0.290782
# 4                              0.316116
# ...                                 ...
# 3460                           0.318990
# 3461                           0.298554
# 3462                           0.353778
# 3463                           0.342636
# 3464                           0.360373
#
#       sum_discrimination_additive_train_abs  discrimination_train_pred  \
# 0                                  0.325619                   0.156476
# 1                                  0.304364                   0.234535
# 2                                  0.324563                   0.179566
# 3                                  0.290782                   0.185791
# 4                                  0.316116                   0.144628
# ...                                     ...                        ...
# 3460                               0.343087                   0.087110
# 3461                               0.298554                   0.070248
# 3462                               0.383362                   0.112587
# 3463                               0.377132                   0.119864
# 3464                               0.389957                   0.073205
#
#       sum_discrimination_additive_train_pred  \
# 0                                   0.156476
# 1                                   0.234535
# 2                                   0.179566
# 3                                   0.185791
# 4                                   0.144628
# ...                                      ...
# 3460                                0.087110
# 3461                                0.070248
# 3462                                0.112587
# 3463                                0.119864
# 3464                                0.073205
#
#       sum_discrimination_additive_train_pred_abs  discrimination_test  \
# 0                                       0.156476             0.266667
# 1                                       0.234535            -0.046083
# 2                                       0.179566             0.172619
# 3                                       0.185791             0.137931
# 4                                       0.144628             0.297386
# ...                                          ...                  ...
# 3460                                    0.095907             0.125937
# 3461                                    0.080579             0.336601
# 3462                                    0.129734             0.100478
# 3463                                    0.134787             0.038462
# 3464                                    0.103542            -0.027113
#
#       sum_discrimination_additive_test_pred  \
# 0                                  0.266667
# 1                                 -0.046083
# 2                                  0.172619
# 3                                  0.137931
# 4                                  0.297386
# ...                                     ...
# 3460                               0.125937
# 3461                               0.336601
# 3462                               0.100478
# 3463                               0.038462
# 3464                              -0.027113
#
#       sum_discrimination_additive_test_pred_abs  duration  min_supp  \
# 0                                      0.266667  0.014749         2
# 1                                      0.046083  0.002740         2
# 2                                      0.172619  0.008495         2
# 3                                      0.137931  0.007508         2
# 4                                      0.297386  0.005686         2
# ...                                         ...       ...       ...
# 3460                                   0.389805  2.492604         2
# 3461                                   0.336601  2.443317         2
# 3462                                   0.263158  2.611714         2
# 3463                                   0.038462  2.247641         2
# 3464                                   0.467305  2.281522         2
#
#                                               clf.tree_
# 0     {'feat': 10, 'left': {'value': 1, 'error': 0.0...
# 1     {'feat': 10, 'left': {'value': 1, 'error': 0.0...
# 2     {'feat': 10, 'left': {'value': 1, 'error': 0.0...
# 3     {'feat': 10, 'left': {'value': 1, 'error': 0.0...
# 4     {'feat': 10, 'left': {'value': 1, 'error': 0.0...
# ...                                                 ...
# 3460  {'feat': 7, 'left': {'feat': 0, 'left': {'feat...
# 3461  {'feat': 0, 'left': {'feat': 5, 'left': {'valu...
# 3462  {'feat': 5, 'left': {'feat': 0, 'left': {'valu...
# 3463  {'feat': 3, 'left': {'feat': 5, 'left': {'valu...
# 3464  {'feat': 5, 'left': {'feat': 0, 'left': {'feat...
#
# [3465 rows x 20 columns]

# %%
list_k = df_pydl["k"].unique()
list_k = [0, 5, 10, 50, 100, 150, 200, 250, 500, 1000, 100000]

# %%
_COLORS3 = ['#ff0000', '#00ff00', '#0000ff']
_COLORS5 = ['#008080', '#ffa500', '#00ff00', '#0000ff', '#ff1493']
_COLORS8 = ['#006400', '#ff0000', '#ffd700', '#c71585', '#00ff00', '#00ffff', '#0000ff', '#1e90ff']
_COLORS11 = ['#8b4513', '#006400', '#4682b4', '#4b0082', '#ff0000', '#ffff00', '#00ff7f', '#00ffff', '#ff00ff', '#ffff54',
             '#ffe4c4']
_COLORS11 = ['#8b4513', '#006400', '#000080', '#ff0000', '#ffff00', '#00ff7f', '#00ffff', '#ff00ff', '#eee8aa', '#6495ed',
             '#ff69b4']

# %%
def graphh(axe1, axe2, x_size, y_size):
    legends = ['< 0', '< 0.1', '< 0.2', '< 0.3', 'no relab']
    fig, axes = plt.subplots()

    for depth in df_sklearn['depth'].unique():
        index_legends = 0
        y_values = list()
        x_values = list()
        y_values_pydl = list()
        x_values_pydl = list()
        for x_axe, y_axe in axe1:

            tmp = df_sklearn.loc[(df_sklearn["k"] == 0) & (df_sklearn["depth"] == depth)]
            x_values.append(tmp[x_axe].mean())
            y_values.append(tmp[y_axe].mean())

            if index_legends == 0:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS8[index_legends], marker='x')
            else:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS8[index_legends])

            tmp = df_pydl.loc[(df_pydl["k"] == 0) & (df_pydl["depth"] == depth)]
            x_values_pydl.append(tmp[x_axe].mean())
            y_values_pydl.append(tmp[y_axe].mean())

            if index_legends == 0:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS8[index_legends], marker='x')
            else:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS8[index_legends])

            index_legends +=1
        plt.plot(x_values, y_values, label="Sklearn (relab)", c=_COLORS3[0], linestyle="-")
        plt.plot(x_values_pydl, y_values_pydl, label="Pydl (relab)", c=_COLORS3[1], linestyle="-")

        """
        y_values = list()
        x_values = list()
        x_axe = axe2[0]
        y_axe = axe2[1]
        index_legends = 0
        #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
        for k in [0, 5, 10, 100, 500, 1000, 5000]:
            tmp = df_pydl.loc[(df_pydl["k"] == k) & (df_pydl["depth"] == depth)]
            x_values.append(tmp[x_axe].mean())
            y_values.append(tmp[y_axe].mean())

            if index_legends == 0:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends], marker='x')
            else:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends])

            index_legends +=1

        plt.plot(x_values, y_values, label="Pydl (constantes)", c=colors4[2])
        """
        # PYDL 2
        y_values = list()
        x_values = list()
        x_axe = axe2[0]
        y_axe = axe2[1]
        index_legends = 0
        #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
        for k in list_k:
            tmp = df_pydl2.loc[(df_pydl2["k"] == k) & (df_pydl2["depth"] == depth)]
            x_values.append(tmp[x_axe].mean())
            y_values.append(tmp[y_axe].mean())

            if index_legends == 0:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends], marker='x')
            else:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends])

            index_legends +=1

        plt.plot(x_values, y_values, label="Pydl (DATC)", c=_COLORS3[2], linestyle="-")

        """
        # PYDL 3
        y_values = list()
        x_values = list()
        x_axe = axe2[0]
        y_axe = axe2[1]
        index_legends = 0
        #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
        for k in [0, 5, 10, 100, 500, 1000, 5000]:
            tmp = df_pydl3.loc[(df_pydl3["k"] == k) & (df_pydl3["depth"] == depth)]
            x_values.append(tmp[x_axe].mean())
            y_values.append(tmp[y_axe].mean())

            if index_legends == 0:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends], marker='x')
            else:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends])

            index_legends +=1

        plt.plot(x_values, y_values, label="Pydl (constantes3)", c=colors4[4])
        """
        
        plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
        plt.title(f'Depth {depth}')
        plt.ylabel('discrimination')
        plt.xlabel('accuracy')
        plt.ylim(y_size[0], y_size[1])
        plt.xlim(x_size[0], x_size[1])
        plt.legend()

        plt.show()

# %% [markdown]
# # Train

# %% [markdown]
# ## Threshold

# %% [markdown]
# ### Train. Threshold

# %%
graphh([('accuracy_pred', 'discrimination_train_pred'), ('accuracy_relab_0.3', 'discrimination_relab_0.3'), 
        ('accuracy_relab_0.25', 'discrimination_relab_0.25'), ('accuracy_relab_0.2', 'discrimination_relab_0.2'), 
        ('accuracy_relab_0.15', 'discrimination_relab_0.15'), ('accuracy_relab_0.1', 'discrimination_relab_0.1'), 
        ('accuracy_relab_0.05', 'discrimination_relab_0.05'), ('accuracy_relab_0.0', 'discrimination_relab_0.0')], 
       ("accuracy_pred", "sum_discrimination_additive_train_pred"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# ### Train. Threshold Absolute

# %%
graphh([('accuracy_pred', 'sum_discrimination_additive_train_pred_abs'), ('accuracy_relab_0.3', 'discrimination_relab_abs_0.3'), 
        ('accuracy_relab_0.25', 'discrimination_relab_abs_0.25'), ('accuracy_relab_0.2', 'discrimination_relab_abs_0.2'), 
        ('accuracy_relab_0.15', 'discrimination_relab_abs_0.15'), ('accuracy_relab_0.1', 'discrimination_relab_abs_0.1'),
        ('accuracy_relab_0.05', 'discrimination_relab_abs_0.05'), ('accuracy_relab_0.0', 'discrimination_relab_abs_0.0')], ("accuracy_pred", "sum_discrimination_additive_train_pred_abs"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# ## Leaf

# %% [markdown]
# ### Train. Leaf

# %%
graphh([('accuracy_pred', 'discrimination_train_pred'), ('accuracy_relab_1', 'discrimination_relab_1'), ('accuracy_relab_2', 'discrimination_relab_2'), ('accuracy_relab_3', 'discrimination_relab_3')], ("accuracy_pred", "discrimination_train_pred"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# ### Train. Leaf Absolute

# %%
graphh([('accuracy_pred', 'sum_discrimination_additive_train_pred_abs'), ('accuracy_relab_1', 'discrimination_relab_abs_1'), ('accuracy_relab_2', 'discrimination_relab_abs_2'), ('accuracy_relab_3', 'discrimination_relab_abs_3')], ("accuracy_pred", "sum_discrimination_additive_train_pred_abs"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# # Test

# %% [markdown]
# ## Threshold

# %% [markdown]
# ### Test. Threshold

# %%
graphh([('accuracy_test', 'discrimination_test'), ('accuracy_relab_test_0.3', 'discrimination_relab_test_0.3'), ('accuracy_relab_test_0.2', 'discrimination_relab_test_0.2'), ('accuracy_relab_test_0.1', 'discrimination_relab_test_0.1'), ('accuracy_relab_test_0.0', 'discrimination_relab_test_0.0'), ], ("accuracy_test", "discrimination_test"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# ### Test. Threshold Absolute

# %%
graphh([('accuracy_test', 'sum_discrimination_additive_test_pred_abs'), ('accuracy_relab_test_0.3', 'discrimination_relab_test_abs_0.3'), ('accuracy_relab_test_0.2', 'discrimination_relab_test_abs_0.2'), ('accuracy_relab_test_0.1', 'discrimination_relab_test_abs_0.1'), ('accuracy_relab_test_0.0', 'discrimination_relab_test_abs_0.0')], ("accuracy_test", "sum_discrimination_additive_test_pred_abs"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# ## Leaf

# %% [markdown]
# ### Test. Leaf

# %%
graphh([('accuracy_test', 'discrimination_test'), ('accuracy_relab_test_1', 'discrimination_relab_test_1'), ('accuracy_relab_test_2', 'discrimination_relab_test_2'), ('accuracy_relab_test_3', 'discrimination_relab_test_3')], ("accuracy_test", "discrimination_test"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# ### Test. Leaf Absolute

# %%
graphh([('accuracy_test', 'sum_discrimination_additive_test_pred_abs'), ('accuracy_relab_test_1', 'discrimination_relab_test_abs_1'), ('accuracy_relab_test_2', 'discrimination_relab_test_abs_2'), ('accuracy_relab_test_3', 'discrimination_relab_test_abs_3')], ("accuracy_test", "sum_discrimination_additive_test_pred_abs"), (0, 1), (-0.2, 0.8))

# %%
legends = ['< 0', '< 0.1', '< 0.2', '< 0.3', 'no relab']
fig, axes = plt.subplots()

for depth in df_sklearn['depth'].unique():
    index_legends = 0
    y_values = list()
    x_values = list()
    y_values_pydl = list()
    x_values_pydl = list()
    axe2 = ("accuracy_pred", "sum_discrimination_additive_train_pred")
    x_axe = axe2[0]
    y_axe = axe2[1]
    index_legends = 0
    #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
    for k in list_k:
        tmp = df_pydl2.loc[(df_pydl2["k"] == k) & (df_pydl2["depth"] == depth)]
        x_values.append(tmp[x_axe].mean())
        y_values.append(tmp[y_axe].mean())

        if index_legends == 0:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends], marker='x')
        else:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends])

        index_legends +=1

    plt.plot(x_values, y_values, label="Pydl (DATC)", c=_COLORS3[1])

    # PYDL 2
    y_values = list()
    x_values = list()

    axe2 = ("accuracy_pred", "sum_discrimination_additive_train_pred_abs")
    x_axe = axe2[0]
    y_axe = axe2[1]
    index_legends = 0
    #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
    for k in list_k:
        tmp = df_pydl2.loc[(df_pydl2["k"] == k) & (df_pydl2["depth"] == depth)]
        x_values.append(tmp[x_axe].mean())
        y_values.append(tmp[y_axe].mean())

        if index_legends == 0:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends], marker='x')
        else:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends])

        index_legends +=1

    plt.plot(x_values, y_values, label="Pydl (DATC (abs))", c=_COLORS3[2])


    plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
    plt.title(f'Depth {depth}')
    plt.ylabel('discrimination')
    plt.xlabel('accuracy')
    plt.legend()

    plt.show()

# %%
colors11 = _COLORS11.copy()
colors5 = _COLORS11.copy()
colors4 = _COLORS5.copy()
legends = ['< 0', '< 0.1', '< 0.2', '< 0.3', 'no relab']
fig, axes = plt.subplots()

for depth in df_pydl['depth'].unique():
    index_legends = 0
    y_values = list()
    x_values = list()
    y_values_pydl = list()
    x_values_pydl = list()

    index_legends = 0
    #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
    for x_axe, y_axe in [('accuracy_pred', 'discrimination_train_pred'), ('accuracy_relab_0.3', 'discrimination_relab_0.3'), 
        ('accuracy_relab_0.25', 'discrimination_relab_0.25'), ('accuracy_relab_0.2', 'discrimination_relab_0.2'), 
        ('accuracy_relab_0.15', 'discrimination_relab_0.15'), ('accuracy_relab_0.1', 'discrimination_relab_0.1'), 
        ('accuracy_relab_0.05', 'discrimination_relab_0.05'), ('accuracy_relab_0.0', 'discrimination_relab_0.0')]:
        tmp = df_pydl.loc[(df_pydl["k"] == 0) & (df_pydl["depth"] == depth)]
        x_values.append(tmp[x_axe].mean())
        y_values.append(tmp[y_axe].mean())

        if index_legends == 0:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends], marker='x')
        else:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends])

        index_legends +=1

    plt.plot(x_values, y_values, label="Pydl (relab)", c=_COLORS3[1])

    # PYDL 2
    y_values = list()
    x_values = list()
    
    index_legends = 0
    #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
    for x_axe, y_axe  in [('accuracy_pred', 'sum_discrimination_additive_train_pred_abs'), ('accuracy_relab_0.3', 'discrimination_relab_abs_0.3'), 
        ('accuracy_relab_0.25', 'discrimination_relab_abs_0.25'), ('accuracy_relab_0.2', 'discrimination_relab_abs_0.2'), 
        ('accuracy_relab_0.15', 'discrimination_relab_abs_0.15'), ('accuracy_relab_0.1', 'discrimination_relab_abs_0.1'), 
        ('accuracy_relab_0.05', 'discrimination_relab_abs_0.05'), ('accuracy_relab_0.0', 'discrimination_relab_abs_0.0')]:
        tmp = df_pydl.loc[(df_pydl["k"] == 0) & (df_pydl["depth"] == depth)]
        x_values.append(tmp[x_axe].mean())
        y_values.append(tmp[y_axe].mean())

        if index_legends == 0:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends], marker='x')
        else:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends])

        index_legends +=1

    plt.plot(x_values, y_values, label="Pydl (relab (abs))", c=_COLORS3[2])


    plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
    plt.title(f'Depth {depth}')
    plt.ylabel('discrimination')
    plt.xlabel('accuracy')
    plt.legend()

    plt.show()

# %%
colors11 = _COLORS11.copy()
colors5 = _COLORS11.copy()
colors4 = _COLORS5.copy()
legends = ['< 0', '< 0.1', '< 0.2', '< 0.3', 'no relab']
fig, axes = plt.subplots()

for depth in df_pydl['depth'].unique():
    index_legends = 0
    y_values = list()
    x_values = list()
    y_values_pydl = list()
    x_values_pydl = list()

    index_legends = 0
    #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
    for x_axe, y_axe in [('accuracy_pred', 'discrimination_train_pred'), ('accuracy_relab_0.3', 'discrimination_relab_0.3'), 
        ('accuracy_relab_0.25', 'discrimination_relab_0.25'), ('accuracy_relab_0.2', 'discrimination_relab_0.2'), 
        ('accuracy_relab_0.15', 'discrimination_relab_0.15'), ('accuracy_relab_0.1', 'discrimination_relab_0.1'), 
        ('accuracy_relab_0.05', 'discrimination_relab_0.05'), ('accuracy_relab_0.0', 'discrimination_relab_0.0')]:
        tmp = df_pydl.loc[(df_pydl["k"] == 0) & (df_pydl["depth"] == depth)]
        x_values.append(tmp[x_axe].mean())
        y_values.append(tmp[y_axe].mean())

        if index_legends == 0:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends], marker='x')
        else:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends])

        index_legends +=1

    plt.plot(x_values, y_values, label="Pydl (relab)", c=_COLORS3[1])

    # PYDL 2
    y_values = list()
    x_values = list()
    
    index_legends = 0
    #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
    for x_axe, y_axe  in [('accuracy_pred', 'sum_discrimination_additive_train_pred_abs'), ('accuracy_relab_0.3', 'discrimination_relab_abs_0.3'), 
        ('accuracy_relab_0.25', 'discrimination_relab_abs_0.25'), ('accuracy_relab_0.2', 'discrimination_relab_abs_0.2'), 
        ('accuracy_relab_0.15', 'discrimination_relab_abs_0.15'), ('accuracy_relab_0.1', 'discrimination_relab_abs_0.1'), 
        ('accuracy_relab_0.05', 'discrimination_relab_abs_0.05'), ('accuracy_relab_0.0', 'discrimination_relab_abs_0.0')]:
        tmp = df_pydl.loc[(df_pydl["k"] == 0) & (df_pydl["depth"] == depth)]
        x_values.append(tmp[x_axe].mean())
        y_values.append(tmp[y_axe].mean())

        if index_legends == 0:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends], marker='x')
        else:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends])

        index_legends +=1

    plt.plot(x_values, y_values, label="Pydl (relab (abs))", c=_COLORS3[2])


    plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
    plt.title(f'Depth {depth}')
    plt.ylabel('discrimination')
    plt.xlabel('accuracy')
    plt.legend()

    plt.show()
