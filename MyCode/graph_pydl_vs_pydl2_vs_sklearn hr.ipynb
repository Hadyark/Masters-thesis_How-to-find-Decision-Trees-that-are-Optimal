# %%
import pandas
import pandas as pd
import matplotlib.pyplot as plt

# %%
FILE_NAME = "HR"

df_pydl = pandas.read_csv("hr/save/"+FILE_NAME+"_relab.csv")
df_pydl2 = pandas.read_csv("hr2/save/"+FILE_NAME+".csv")
df_sklearn = pandas.read_csv("hr/save/"+FILE_NAME+"_relab_sklearn.csv")

# %%
df_pydl
# Out:
#            k  depth  random_state    clf.error_  clf.accuracy_  \
# 0          0      1             1     49.000000       0.803213
# 1         10      1             1     49.833332       0.799866
# 2         50      1             1     53.166664       0.786479
# 3        100      1             1     57.333332       0.769746
# 4        200      1             1     65.666672       0.736278
# ...      ...    ...           ...           ...            ...
# 1458     400      7            96     96.042755       0.614286
# 1459     500      7            96    108.803436       0.563038
# 1460    1000      7            96    172.606873       0.306800
# 1461    5000      7            96    683.034424      -1.743110
# 1462  100000      7            96  12805.688477     -50.428467
#
#                                 confusion  accuracy_pred  accuracy_test  \
# 0     ((16, 3, 19, 67), (14, 5, 22, 103))       0.803213       0.854839
# 1     ((16, 3, 19, 67), (14, 5, 22, 103))       0.803213       0.854839
# 2     ((16, 3, 19, 67), (14, 5, 22, 103))       0.803213       0.854839
# 3     ((16, 3, 19, 67), (14, 5, 22, 103))       0.803213       0.854839
# 4     ((16, 3, 19, 67), (14, 5, 22, 103))       0.803213       0.854839
# ...                                   ...            ...            ...
# 1458  ((20, 3, 18, 71), (10, 5, 19, 103))       0.819277       0.790323
# 1459  ((20, 3, 18, 71), (10, 5, 19, 103))       0.819277       0.790323
# 1460  ((20, 3, 18, 71), (10, 5, 19, 103))       0.819277       0.790323
# 1461  ((20, 3, 18, 71), (10, 5, 19, 103))       0.819277       0.790323
# 1462  ((20, 3, 18, 71), (10, 5, 19, 103))       0.819277       0.790323
#
#       sum_misclassified_train  discrimination_train  ...  \
# 0                          49              0.083333  ...
# 1                          49              0.083333  ...
# 2                          49              0.083333  ...
# 3                          49              0.083333  ...
# 4                          49              0.083333  ...
# ...                       ...                   ...  ...
# 1458                       45              0.127607  ...
# 1459                       45              0.127607  ...
# 1460                       45              0.127607  ...
# 1461                       45              0.127607  ...
# 1462                       45              0.127607  ...
#
#       discrimination_relab_abs_0.2  accuracy_relab_test_0.2  \
# 0                          0.04900                  0.85483
# 1                          0.04900                  0.85483
# 2                          0.04900                  0.85483
# 3                          0.04900                  0.85483
# 4                          0.04900                  0.85483
# ...                            ...                      ...
# 1458                       0.09586                  0.79032
# 1459                       0.09586                  0.79032
# 1460                       0.09586                  0.79032
# 1461                       0.09586                  0.79032
# 1462                       0.09586                  0.79032
#
#       discrimination_relab_test_0.2  discrimination_relab_test_abs_0.2  \
# 0                          0.206250                           0.206250
# 1                          0.206250                           0.206250
# 2                          0.206250                           0.206250
# 3                          0.206250                           0.206250
# 4                          0.206250                           0.206250
# ...                             ...                                ...
# 1458                       0.037904                           0.037904
# 1459                       0.037904                           0.037904
# 1460                       0.037904                           0.037904
# 1461                       0.037904                           0.037904
# 1462                       0.037904                           0.037904
#
#       accuracy_relab_0.3  discrimination_relab_0.3  \
# 0                0.80321                   0.04900
# 1                0.80321                   0.04900
# 2                0.80321                   0.04900
# 3                0.80321                   0.04900
# 4                0.80321                   0.04900
# ...                  ...                       ...
# 1458             0.81927                   0.09586
# 1459             0.81927                   0.09586
# 1460             0.81927                   0.09586
# 1461             0.81927                   0.09586
# 1462             0.81927                   0.09586
#
#       discrimination_relab_abs_0.3  accuracy_relab_test_0.3  \
# 0                          0.04900                  0.85483
# 1                          0.04900                  0.85483
# 2                          0.04900                  0.85483
# 3                          0.04900                  0.85483
# 4                          0.04900                  0.85483
# ...                            ...                      ...
# 1458                       0.09586                  0.79032
# 1459                       0.09586                  0.79032
# 1460                       0.09586                  0.79032
# 1461                       0.09586                  0.79032
# 1462                       0.09586                  0.79032
#
#       discrimination_relab_test_0.3  discrimination_relab_test_abs_0.3
# 0                          0.206250                           0.206250
# 1                          0.206250                           0.206250
# 2                          0.206250                           0.206250
# 3                          0.206250                           0.206250
# 4                          0.206250                           0.206250
# ...                             ...                                ...
# 1458                       0.037904                           0.037904
# 1459                       0.037904                           0.037904
# 1460                       0.037904                           0.037904
# 1461                       0.037904                           0.037904
# 1462                       0.037904                           0.037904
#
# [1463 rows x 63 columns]

# %%
df_pydl2
# Out:
#            k  depth  random_state  clf.error_  clf.accuracy_  \
# 0          0      1             1   49.000000       0.803213
# 1         10      1             1   49.490078       0.801245
# 2         50      1             1   51.450397       0.793372
# 3        100      1             1   53.900795       0.783531
# 4        200      1             1   58.801590       0.763849
# ...      ...    ...           ...         ...            ...
# 1458     400      7            96   62.955162       0.747168
# 1459     500      7            96   63.443951       0.745205
# 1460    1000      7            96   65.887901       0.735390
# 1461    5000      7            96   66.000000       0.734940
# 1462  100000      7            96   66.000000       0.734940
#
#                                 confusion  accuracy_pred  accuracy_test  \
# 0     ((16, 3, 19, 67), (14, 5, 22, 103))       0.803213       0.854839
# 1     ((16, 3, 19, 67), (14, 5, 22, 103))       0.803213       0.854839
# 2     ((16, 3, 19, 67), (14, 5, 22, 103))       0.803213       0.854839
# 3     ((16, 3, 19, 67), (14, 5, 22, 103))       0.803213       0.854839
# 4     ((16, 3, 19, 67), (14, 5, 22, 103))       0.803213       0.854839
# ...                                   ...            ...            ...
# 1458    ((3, 0, 35, 74), (3, 0, 26, 108))       0.755020       0.693548
# 1459    ((3, 0, 35, 74), (3, 0, 26, 108))       0.755020       0.693548
# 1460    ((3, 0, 35, 74), (3, 0, 26, 108))       0.755020       0.693548
# 1461    ((0, 0, 38, 74), (0, 0, 29, 108))       0.730924       0.629032
# 1462    ((0, 0, 38, 74), (0, 0, 29, 108))       0.730924       0.629032
#
#       sum_misclassified_train  discrimination_train  ...  \
# 0                          49              0.083333  ...
# 1                          49              0.083333  ...
# 2                          49              0.083333  ...
# 3                          49              0.083333  ...
# 4                          49              0.083333  ...
# ...                       ...                   ...  ...
# 1458                       61              0.127607  ...
# 1459                       61              0.127607  ...
# 1460                       61              0.127607  ...
# 1461                       67              0.127607  ...
# 1462                       67              0.127607  ...
#
#       sum_discrimination_additive_train_abs  discrimination_train_pred  \
# 0                                  0.083333                   0.049008
# 1                                  0.083333                   0.049008
# 2                                  0.083333                   0.049008
# 3                                  0.083333                   0.049008
# 4                                  0.083333                   0.049008
# ...                                     ...                        ...
# 1458                               0.127607                   0.004888
# 1459                               0.127607                   0.004888
# 1460                               0.127607                   0.004888
# 1461                               0.550965                   0.000000
# 1462                               0.550965                   0.000000
#
#       sum_discrimination_additive_train_pred  \
# 0                                   0.049008
# 1                                   0.049008
# 2                                   0.049008
# 3                                   0.049008
# 4                                   0.049008
# ...                                      ...
# 1458                                0.004888
# 1459                                0.004888
# 1460                                0.004888
# 1461                                0.000000
# 1462                                0.000000
#
#       sum_discrimination_additive_train_pred_abs  discrimination_test  \
# 0                                       0.049008             0.206250
# 1                                       0.049008             0.206250
# 2                                       0.049008             0.206250
# 3                                       0.049008             0.206250
# 4                                       0.049008             0.206250
# ...                                          ...                  ...
# 1458                                    0.004888            -0.033445
# 1459                                    0.004888            -0.033445
# 1460                                    0.004888            -0.033445
# 1461                                    0.000000             0.000000
# 1462                                    0.000000             0.000000
#
#       sum_discrimination_additive_test_pred  \
# 0                                  0.206250
# 1                                  0.206250
# 2                                  0.206250
# 3                                  0.206250
# 4                                  0.206250
# ...                                     ...
# 1458                              -0.033445
# 1459                              -0.033445
# 1460                              -0.033445
# 1461                               0.000000
# 1462                               0.000000
#
#       sum_discrimination_additive_test_pred_abs    duration  min_supp  \
# 0                                      0.206250    0.023105         2
# 1                                      0.206250    0.017934         2
# 2                                      0.206250    0.017392         2
# 3                                      0.206250    0.016255         2
# 4                                      0.206250    0.033458         2
# ...                                         ...         ...       ...
# 1458                                   0.033445  300.950624         2
# 1459                                   0.033445  300.980652         2
# 1460                                   0.033445  300.710188         2
# 1461                                   0.000000  301.020723         2
# 1462                                   0.000000  301.113005         2
#
#                                               clf.tree_
# 0     {'feat': 61, 'left': {'value': 1, 'error': 8.0...
# 1     {'feat': 61, 'left': {'value': 1, 'error': 8.4...
# 2     {'feat': 61, 'left': {'value': 1, 'error': 10....
# 3     {'feat': 61, 'left': {'value': 1, 'error': 12....
# 4     {'feat': 61, 'left': {'value': 1, 'error': 17....
# ...                                                 ...
# 1458  {'feat': 40, 'left': {'value': 1, 'error': 1.9...
# 1459  {'feat': 40, 'left': {'value': 1, 'error': 2.4...
# 1460  {'feat': 40, 'left': {'value': 1, 'error': 4.8...
# 1461  {'feat': 0, 'left': {'value': 0, 'error': 29.0...
# 1462  {'feat': 0, 'left': {'value': 0, 'error': 29.0...
#
# [1463 rows x 21 columns]

# %%
list_k = df_pydl["k"].unique()

# %%
_COLORS3 = ['#ff0000', '#00ff00', '#0000ff']
_COLORS5 = ['#008080', '#ffa500', '#00ff00', '#0000ff', '#ff1493']
_COLORS8 = ['#006400', '#ff0000', '#ffd700', '#c71585', '#00ff00', '#00ffff', '#0000ff', '#1e90ff']
_COLORS11 = ['#8b4513', '#006400', '#4682b4', '#4b0082', '#ff0000', '#ffff00', '#00ff7f', '#00ffff', '#ff00ff', '#ffff54',
             '#ffe4c4']
_COLORS11 = ['#8b4513', '#006400', '#000080', '#ff0000', '#ffff00', '#00ff7f', '#00ffff', '#ff00ff', '#eee8aa', '#6495ed',
             '#ff69b4']

# %%
def graphh(axe1, axe2, x_size, y_size):
    legends = ['< 0', '< 0.1', '< 0.2', '< 0.3', 'no relab']
    fig, axes = plt.subplots()

    for depth in df_sklearn['depth'].unique():
        index_legends = 0
        y_values = list()
        x_values = list()
        y_values_pydl = list()
        x_values_pydl = list()
        for x_axe, y_axe in axe1:

            tmp = df_sklearn.loc[(df_sklearn["k"] == 0) & (df_sklearn["depth"] == depth)]
            x_values.append(tmp[x_axe].mean())
            y_values.append(tmp[y_axe].mean())

            if index_legends == 0:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS8[index_legends], marker='x')
            else:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS8[index_legends])

            tmp = df_pydl.loc[(df_pydl["k"] == 0) & (df_pydl["depth"] == depth)]
            x_values_pydl.append(tmp[x_axe].mean())
            y_values_pydl.append(tmp[y_axe].mean())

            if index_legends == 0:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS8[index_legends], marker='x')
            else:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS8[index_legends])

            index_legends +=1
        plt.plot(x_values, y_values, label="Sklearn (relab)", c=_COLORS3[0], linestyle="-")
        plt.plot(x_values_pydl, y_values_pydl, label="Pydl (relab)", c=_COLORS3[1], linestyle="-")

        """
        y_values = list()
        x_values = list()
        x_axe = axe2[0]
        y_axe = axe2[1]
        index_legends = 0
        #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
        for k in [0, 5, 10, 100, 500, 1000, 5000]:
            tmp = df_pydl.loc[(df_pydl["k"] == k) & (df_pydl["depth"] == depth)]
            x_values.append(tmp[x_axe].mean())
            y_values.append(tmp[y_axe].mean())

            if index_legends == 0:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends], marker='x')
            else:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends])

            index_legends +=1

        plt.plot(x_values, y_values, label="Pydl (constantes)", c=colors4[2])
        """
        # PYDL 2
        y_values = list()
        x_values = list()
        x_axe = axe2[0]
        y_axe = axe2[1]
        index_legends = 0
        #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
        for k in list_k:
            tmp = df_pydl2.loc[(df_pydl2["k"] == k) & (df_pydl2["depth"] == depth)]
            x_values.append(tmp[x_axe].mean())
            y_values.append(tmp[y_axe].mean())

            if index_legends == 0:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends], marker='x')
            else:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends])

            index_legends +=1

        plt.plot(x_values, y_values, label="Pydl (DATC)", c=_COLORS3[2], linestyle="-")

        """
        # PYDL 3
        y_values = list()
        x_values = list()
        x_axe = axe2[0]
        y_axe = axe2[1]
        index_legends = 0
        #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
        for k in [0, 5, 10, 100, 500, 1000, 5000]:
            tmp = df_pydl3.loc[(df_pydl3["k"] == k) & (df_pydl3["depth"] == depth)]
            x_values.append(tmp[x_axe].mean())
            y_values.append(tmp[y_axe].mean())

            if index_legends == 0:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends], marker='x')
            else:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends])

            index_legends +=1

        plt.plot(x_values, y_values, label="Pydl (constantes3)", c=colors4[4])
        """
        
        plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
        plt.title(f'Depth {depth}')
        plt.ylabel('discrimination')
        plt.xlabel('accuracy')
        plt.ylim(y_size[0], y_size[1])
        plt.xlim(x_size[0], x_size[1])
        plt.legend()

        plt.show()

# %% [markdown]
# # Train

# %% [markdown]
# ## Threshold

# %% [markdown]
# ### Train. Threshold

# %%
graphh([('accuracy_pred', 'discrimination_train_pred'), ('accuracy_relab_0.3', 'discrimination_relab_0.3'), ('accuracy_relab_0.2', 'discrimination_relab_0.2'), ('accuracy_relab_0.1', 'discrimination_relab_0.1'), ('accuracy_relab_0.0', 'discrimination_relab_0.0')], ("accuracy_pred", "sum_discrimination_additive_train_pred"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# ### Train. Threshold Absolute

# %%
graphh([('accuracy_pred', 'sum_discrimination_additive_train_pred_abs'), ('accuracy_relab_0.3', 'discrimination_relab_abs_0.3'), ('accuracy_relab_0.2', 'discrimination_relab_abs_0.2'), ('accuracy_relab_0.1', 'discrimination_relab_abs_0.1'),('accuracy_relab_0.0', 'discrimination_relab_abs_0.0')], ("accuracy_pred", "sum_discrimination_additive_train_pred_abs"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# ## Leaf

# %% [markdown]
# ### Train. Leaf

# %%
graphh([('accuracy_pred', 'discrimination_train_pred'), ('accuracy_relab_1', 'discrimination_relab_1'), ('accuracy_relab_2', 'discrimination_relab_2'), ('accuracy_relab_3', 'discrimination_relab_3')], ("accuracy_pred", "discrimination_train_pred"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# ### Train. Leaf Absolute

# %%
graphh([('accuracy_pred', 'sum_discrimination_additive_train_pred_abs'), ('accuracy_relab_1', 'discrimination_relab_abs_1'), ('accuracy_relab_2', 'discrimination_relab_abs_2'), ('accuracy_relab_3', 'discrimination_relab_abs_3')], ("accuracy_pred", "sum_discrimination_additive_train_pred_abs"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# # Test

# %% [markdown]
# ## Threshold

# %% [markdown]
# ### Test. Threshold

# %%
graphh([('accuracy_test', 'discrimination_test'), ('accuracy_relab_test_0.3', 'discrimination_relab_test_0.3'), ('accuracy_relab_test_0.2', 'discrimination_relab_test_0.2'), ('accuracy_relab_test_0.1', 'discrimination_relab_test_0.1'), ('accuracy_relab_test_0.0', 'discrimination_relab_test_0.0'), ], ("accuracy_test", "discrimination_test"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# ### Test. Threshold Absolute

# %%
graphh([('accuracy_test', 'sum_discrimination_additive_test_pred_abs'), ('accuracy_relab_test_0.3', 'discrimination_relab_test_abs_0.3'), ('accuracy_relab_test_0.2', 'discrimination_relab_test_abs_0.2'), ('accuracy_relab_test_0.1', 'discrimination_relab_test_abs_0.1'), ('accuracy_relab_test_0.0', 'discrimination_relab_test_abs_0.0')], ("accuracy_test", "sum_discrimination_additive_test_pred_abs"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# ## Leaf

# %% [markdown]
# ### Test. Leaf

# %%
graphh([('accuracy_test', 'discrimination_test'), ('accuracy_relab_test_1', 'discrimination_relab_test_1'), ('accuracy_relab_test_2', 'discrimination_relab_test_2'), ('accuracy_relab_test_3', 'discrimination_relab_test_3')], ("accuracy_test", "discrimination_test"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# ### Test. Leaf Absolute

# %%
graphh([('accuracy_test', 'sum_discrimination_additive_test_pred_abs'), ('accuracy_relab_test_1', 'discrimination_relab_test_abs_1'), ('accuracy_relab_test_2', 'discrimination_relab_test_abs_2'), ('accuracy_relab_test_3', 'discrimination_relab_test_abs_3')], ("accuracy_test", "sum_discrimination_additive_test_pred_abs"), (0, 1), (-0.2, 0.8))

# %%
legends = ['< 0', '< 0.1', '< 0.2', '< 0.3', 'no relab']
fig, axes = plt.subplots()

for depth in df_sklearn['depth'].unique():
    index_legends = 0
    y_values = list()
    x_values = list()
    y_values_pydl = list()
    x_values_pydl = list()
    axe2 = ("accuracy_pred", "sum_discrimination_additive_train_pred")
    x_axe = axe2[0]
    y_axe = axe2[1]
    index_legends = 0
    #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
    for k in list_k:
        tmp = df_pydl2.loc[(df_pydl2["k"] == k) & (df_pydl2["depth"] == depth)]
        x_values.append(tmp[x_axe].mean())
        y_values.append(tmp[y_axe].mean())

        if index_legends == 0:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends], marker='x')
        else:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends])

        index_legends +=1

    plt.plot(x_values, y_values, label="Pydl (DATC)", c=_COLORS3[1])

    # PYDL 2
    y_values = list()
    x_values = list()

    axe2 = ("accuracy_pred", "sum_discrimination_additive_train_pred_abs")
    x_axe = axe2[0]
    y_axe = axe2[1]
    index_legends = 0
    #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
    for k in list_k:
        tmp = df_pydl2.loc[(df_pydl2["k"] == k) & (df_pydl2["depth"] == depth)]
        x_values.append(tmp[x_axe].mean())
        y_values.append(tmp[y_axe].mean())

        if index_legends == 0:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends], marker='x')
        else:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=_COLORS11[index_legends])

        index_legends +=1

    plt.plot(x_values, y_values, label="Pydl (DATC (abs))", c=_COLORS3[2])


    plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
    plt.title(f'Depth {depth}')
    plt.ylabel('discrimination')
    plt.xlabel('accuracy')
    plt.legend()

    plt.show()

# %%
colors11 = _COLORS11.copy()
colors5 = _COLORS11.copy()
colors4 = _COLORS5.copy()
legends = ['< 0', '< 0.1', '< 0.2', '< 0.3', 'no relab']
fig, axes = plt.subplots()

for depth in df_sklearn['depth'].unique():
    index_legends = 0
    y_values = list()
    x_values = list()
    y_values_pydl = list()
    x_values_pydl = list()
    axe2 = ("accuracy_pred", "sum_discrimination_additive_train_pred")
    x_axe = axe2[0]
    y_axe = axe2[1]
    index_legends = 0
    #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
    for k in list_k:
        tmp = df_pydl2.loc[(df_pydl2["k"] == k) & (df_pydl2["depth"] == depth)]
        x_values.append(tmp[x_axe].mean())
        y_values.append(tmp[y_axe].mean())

        if index_legends == 0:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends], marker='x')
        else:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends])

        index_legends +=1

    plt.plot(x_values, y_values, label="Pydl (DATC)", c=colors4[2])

    # PYDL 2
    y_values = list()
    x_values = list()

    axe2 = ("accuracy_pred", "sum_discrimination_additive_train_pred_abs")
    x_axe = axe2[0]
    y_axe = axe2[1]
    index_legends = 0
    #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
    for k in list_k:
        tmp = df_pydl2.loc[(df_pydl2["k"] == k) & (df_pydl2["depth"] == depth)]
        x_values.append(tmp[x_axe].mean())
        y_values.append(tmp[y_axe].mean())

        if index_legends == 0:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends], marker='x')
        else:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends])

        index_legends +=1

    plt.plot(x_values, y_values, label="Pydl (DATC abs)", c=colors4[3])


    plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
    plt.title(f'Depth {depth}')
    plt.ylabel('discrimination')
    plt.xlabel('accuracy')
    plt.legend()

    plt.show()

# %%
colors11 = _COLORS11.copy()
colors5 = _COLORS11.copy()
colors4 = _COLORS5.copy()
legends = ['< 0', '< 0.1', '< 0.2', '< 0.3', 'no relab']
fig, axes = plt.subplots()

for depth in df_sklearn['depth'].unique():
    index_legends = 0
    y_values = list()
    x_values = list()
    y_values_pydl = list()
    x_values_pydl = list()
    axe2 = ("accuracy_pred", "sum_discrimination_additive_train_pred")
    x_axe = axe2[0]
    y_axe = axe2[1]
    index_legends = 0
    #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
    for k in list_k:
        tmp = df_pydl.loc[(df_pydl["k"] == k) & (df_pydl["depth"] == depth)]
        x_values.append(tmp[x_axe].mean())
        y_values.append(tmp[y_axe].mean())

        if index_legends == 0:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends], marker='x')
        else:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends])

        index_legends +=1

    plt.plot(x_values, y_values, label="Pydl (relab)", c=colors4[2])

    # PYDL 2
    y_values = list()
    x_values = list()

    axe2 = ("accuracy_pred", "sum_discrimination_additive_train_pred_abs")
    x_axe = axe2[0]
    y_axe = axe2[1]
    index_legends = 0
    #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
    for k in list_k:
        tmp = df_pydl.loc[(df_pydl["k"] == k) & (df_pydl["depth"] == depth)]
        x_values.append(tmp[x_axe].mean())
        y_values.append(tmp[y_axe].mean())

        if index_legends == 0:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends], marker='x')
        else:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends])

        index_legends +=1

    plt.plot(x_values, y_values, label="Pydl (relab abs)", c=colors4[3])


    plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
    plt.title(f'Depth {depth}')
    plt.ylabel('discrimination')
    plt.xlabel('accuracy')
    plt.legend()

    plt.show()
