# %%
import pandas
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('max_columns', None)
FILE_NAME = "census_income"

df_pydl = pandas.read_csv("census_income/save/"+FILE_NAME+"_relab.csv")
df_pydl2 = pandas.read_csv("census_income2/save/"+FILE_NAME+".csv")
df_sklearn = pandas.read_csv("census_income/save/"+FILE_NAME+"_relab_sklearn.csv")

# %%
df_pydl
# Out:
#            k  depth  random_state   clf.error_  clf.accuracy_  accuracy_pred  \
# 0          0      1             2  2856.000000       0.762948       0.762948
# 1          0      1             7  2842.000000       0.764110       0.764110
# 2          0      1            12  2900.000000       0.759296       0.759296
# 3          0      1            17  2860.000000       0.762616       0.762533
# 4          0      1            22  2839.000000       0.764359       0.764359
# ...      ...    ...           ...          ...            ...            ...
# 1003  100000      7            77  2941.038086       0.755890       0.760292
# 1004  100000      7            82  2937.699707       0.756167       0.757968
# 1005  100000      7            87  2939.000000       0.756059       0.755976
# 1006  100000      7            92  2938.000000       0.756142       0.756059
# 1007  100000      7            97  2887.530029       0.760331       0.761454
#
#       accuracy_test  sum_misclassified_train  discrimination_train  \
# 0          0.762616                     2856              0.197352
# 1          0.757968                     2842              0.193553
# 2          0.777224                     2900              0.202440
# 3          0.764276                     2861              0.197610
# 4          0.756972                     2839              0.202128
# ...             ...                      ...                   ...
# 1003       0.751328                     2888              0.197487
# 1004       0.760624                     2916              0.198086
# 1005       0.747676                     2940              0.199320
# 1006       0.747344                     2939              0.196619
# 1007       0.746680                     2874              0.193494
#
#       sum_discrimination_additive_train  \
# 0                              0.197352
# 1                              0.193553
# 2                              0.202440
# 3                              0.197610
# 4                              0.202128
# ...                                 ...
# 1003                           0.197487
# 1004                           0.198086
# 1005                           0.199320
# 1006                           0.196619
# 1007                           0.193494
#
#       sum_discrimination_additive_train_abs  discrimination_train_pred  \
# 0                                  0.197352                   0.014486
# 1                                  0.193553                   0.012149
# 2                                  0.202440                   0.014589
# 3                                  0.197610                   0.011584
# 4                                  0.202128                   0.012191
# ...                                     ...                        ...
# 1003                               0.197487                  -0.000530
# 1004                               0.198086                  -0.000217
# 1005                               0.199320                   0.000000
# 1006                               0.196619                   0.000000
# 1007                               0.193494                   0.000259
#
#       sum_discrimination_additive_train_pred  \
# 0                                   0.014486
# 1                                   0.012149
# 2                                   0.014589
# 3                                   0.011584
# 4                                   0.012191
# ...                                      ...
# 1003                               -0.000530
# 1004                               -0.000217
# 1005                                0.000000
# 1006                                0.000000
# 1007                                0.000259
#
#       sum_discrimination_additive_train_pred_abs  discrimination_test  \
# 0                                       0.014486             0.005957
# 1                                       0.012149             0.015371
# 2                                       0.014589             0.005601
# 3                                       0.011584             0.017517
# 4                                       0.012191             0.015000
# ...                                          ...                  ...
# 1003                                    0.000530            -0.004888
# 1004                                    0.000217            -0.005997
# 1005                                    0.000000             0.000000
# 1006                                    0.000000             0.000000
# 1007                                    0.000259            -0.008094
#
#       sum_discrimination_additive_test_pred  \
# 0                                  0.005957
# 1                                  0.015371
# 2                                  0.005601
# 3                                  0.017517
# 4                                  0.015000
# ...                                     ...
# 1003                              -0.004888
# 1004                              -0.005997
# 1005                               0.000000
# 1006                               0.000000
# 1007                              -0.008094
#
#       sum_discrimination_additive_test_pred_abs    duration  min_supp  \
# 0                                      0.005957    0.303321         2
# 1                                      0.015371    0.495664         2
# 2                                      0.005601    0.464104         2
# 3                                      0.017517    0.574968         2
# 4                                      0.015000    0.452100         2
# ...                                         ...         ...       ...
# 1003                                   0.004888  300.732979         2
# 1004                                   0.005997  300.871734         2
# 1005                                   0.000000  300.830105         2
# 1006                                   0.000000  300.788495         2
# 1007                                   0.008094  300.729402         2
#
#                                               clf.tree_  accuracy_relab_1  \
# 0     {'feat': 19, 'left': {'value': 1, 'error': 43....           0.75365
# 1     {'feat': 19, 'left': {'value': 1, 'error': 44....           0.75630
# 2     {'feat': 19, 'left': {'value': 1, 'error': 46....           0.75066
# 3     {'feat': 19, 'left': {'value': 1, 'error': 48....           0.75498
# 4     {'feat': 19, 'left': {'value': 1, 'error': 43....           0.75506
# ...                                                 ...               ...
# 1003  {'feat': 17, 'left': {'value': 1, 'error': 379...           0.76029
# 1004  {'feat': 17, 'left': {'value': 1, 'error': 371...           0.75796
# 1005  {'feat': 38, 'left': {'value': 0, 'error': 105...           0.73862
# 1006  {'feat': 36, 'left': {'value': 0, 'error': 77....           0.25340
# 1007  {'feat': 17, 'left': {'value': 1, 'error': 328...           0.75564
#
#       discrimination_relab_1  discrimination_relab_abs_1  \
# 0                    0.00000                     0.00000
# 1                    0.00000                     0.00000
# 2                    0.00000                     0.00000
# 3                    0.00000                     0.00000
# 4                    0.00000                     0.00000
# ...                      ...                         ...
# 1003                -0.00054                     0.00053
# 1004                -0.00022                     0.00021
# 1005                -0.01560                     0.01559
# 1006                -0.01916                     0.01915
# 1007                 0.00000                     0.00000
#
#       accuracy_relab_test_1  discrimination_relab_test_1  \
# 0                   0.75697                     0.000000
# 1                   0.74634                     0.000000
# 2                   0.76892                     0.000000
# 3                   0.75166                     0.000000
# 4                   0.75132                     0.000000
# ...                     ...                          ...
# 1003                0.75132                    -0.004888
# 1004                0.76062                    -0.005997
# 1005                0.73671                    -0.007980
# 1006                0.26062                    -0.017474
# 1007                0.74900                     0.000000
#
#       discrimination_relab_test_abs_1  accuracy_relab_2  \
# 0                            0.000000           0.23705
# 1                            0.000000           0.23588
# 2                            0.000000           0.24070
# 3                            0.000000           0.23746
# 4                            0.000000           0.23564
# ...                               ...               ...
# 1003                         0.004888           0.76029
# 1004                         0.005997           0.75796
# 1005                         0.007980           0.73862
# 1006                         0.017474           0.25340
# 1007                         0.000000           0.23854
#
#       discrimination_relab_2  discrimination_relab_abs_2  \
# 0                   -0.01449                     0.01448
# 1                   -0.01215                     0.01214
# 2                   -0.01459                     0.01458
# 3                   -0.01159                     0.01158
# 4                   -0.01220                     0.01219
# ...                      ...                         ...
# 1003                -0.00054                     0.00053
# 1004                -0.00022                     0.00021
# 1005                -0.01560                     0.01559
# 1006                -0.01916                     0.01915
# 1007                -0.00026                     0.00025
#
#       accuracy_relab_test_2  discrimination_relab_test_2  \
# 0                   0.23738                    -0.005957
# 1                   0.24203                    -0.015371
# 2                   0.22277                    -0.005601
# 3                   0.23572                    -0.017517
# 4                   0.24302                    -0.015000
# ...                     ...                          ...
# 1003                0.75132                    -0.004888
# 1004                0.76062                    -0.005997
# 1005                0.73671                    -0.007980
# 1006                0.26062                    -0.017474
# 1007                0.25332                     0.008094
#
#       discrimination_relab_test_abs_2  accuracy_relab_3  \
# 0                            0.005957           0.23705
# 1                            0.015371           0.23588
# 2                            0.005601           0.24070
# 3                            0.017517           0.23746
# 4                            0.015000           0.23564
# ...                               ...               ...
# 1003                         0.004888           0.76029
# 1004                         0.005997           0.75796
# 1005                         0.007980           0.73862
# 1006                         0.017474           0.25340
# 1007                         0.008094           0.23854
#
#       discrimination_relab_3  discrimination_relab_abs_3  \
# 0                   -0.01449                     0.01448
# 1                   -0.01215                     0.01214
# 2                   -0.01459                     0.01458
# 3                   -0.01159                     0.01158
# 4                   -0.01220                     0.01219
# ...                      ...                         ...
# 1003                -0.00054                     0.00053
# 1004                -0.00022                     0.00021
# 1005                -0.01560                     0.01559
# 1006                -0.01916                     0.01915
# 1007                -0.00026                     0.00025
#
#       accuracy_relab_test_3  discrimination_relab_test_3  \
# 0                   0.23738                    -0.005957
# 1                   0.24203                    -0.015371
# 2                   0.22277                    -0.005601
# 3                   0.23572                    -0.017517
# 4                   0.24302                    -0.015000
# ...                     ...                          ...
# 1003                0.75132                    -0.004888
# 1004                0.76062                    -0.005997
# 1005                0.73671                    -0.007980
# 1006                0.26062                    -0.017474
# 1007                0.25332                     0.008094
#
#       discrimination_relab_test_abs_3  accuracy_relab_0.0  \
# 0                            0.005957             0.75365
# 1                            0.015371             0.75630
# 2                            0.005601             0.75066
# 3                            0.017517             0.75498
# 4                            0.015000             0.75506
# ...                               ...                 ...
# 1003                         0.004888             0.76029
# 1004                         0.005997             0.75796
# 1005                         0.007980             0.75597
# 1006                         0.017474             0.75605
# 1007                         0.008094             0.75564
#
#       discrimination_relab_0.0  discrimination_relab_abs_0.0  \
# 0                      0.00000                       0.00000
# 1                      0.00000                       0.00000
# 2                      0.00000                       0.00000
# 3                      0.00000                       0.00000
# 4                      0.00000                       0.00000
# ...                        ...                           ...
# 1003                  -0.00054                       0.00053
# 1004                  -0.00022                       0.00021
# 1005                   0.00000                       0.00000
# 1006                   0.00000                       0.00000
# 1007                   0.00000                       0.00000
#
#       accuracy_relab_test_0.0  discrimination_relab_test_0.0  \
# 0                     0.75697                       0.000000
# 1                     0.74634                       0.000000
# 2                     0.76892                       0.000000
# 3                     0.75166                       0.000000
# 4                     0.75132                       0.000000
# ...                       ...                            ...
# 1003                  0.75132                      -0.004888
# 1004                  0.76062                      -0.005997
# 1005                  0.74767                       0.000000
# 1006                  0.74734                       0.000000
# 1007                  0.74900                       0.000000
#
#       discrimination_relab_test_abs_0.0  accuracy_relab_0.1  \
# 0                              0.000000             0.76294
# 1                              0.000000             0.76411
# 2                              0.000000             0.75929
# 3                              0.000000             0.76253
# 4                              0.000000             0.76435
# ...                                 ...                 ...
# 1003                           0.004888             0.76029
# 1004                           0.005997             0.75796
# 1005                           0.000000             0.75597
# 1006                           0.000000             0.75605
# 1007                           0.000000             0.76145
#
#       discrimination_relab_0.1  discrimination_relab_abs_0.1  \
# 0                      0.01448                       0.01448
# 1                      0.01214                       0.01214
# 2                      0.01458                       0.01458
# 3                      0.01158                       0.01158
# 4                      0.01219                       0.01219
# ...                        ...                           ...
# 1003                  -0.00054                       0.00053
# 1004                  -0.00022                       0.00021
# 1005                   0.00000                       0.00000
# 1006                   0.00000                       0.00000
# 1007                   0.00025                       0.00025
#
#       accuracy_relab_test_0.1  discrimination_relab_test_0.1  \
# 0                     0.76261                       0.005957
# 1                     0.75796                       0.015371
# 2                     0.77722                       0.005601
# 3                     0.76427                       0.017517
# 4                     0.75697                       0.015000
# ...                       ...                            ...
# 1003                  0.75132                      -0.004888
# 1004                  0.76062                      -0.005997
# 1005                  0.74767                       0.000000
# 1006                  0.74734                       0.000000
# 1007                  0.74667                      -0.008094
#
#       discrimination_relab_test_abs_0.1  accuracy_relab_0.2  \
# 0                              0.005957             0.76294
# 1                              0.015371             0.76411
# 2                              0.005601             0.75929
# 3                              0.017517             0.76253
# 4                              0.015000             0.76435
# ...                                 ...                 ...
# 1003                           0.004888             0.76029
# 1004                           0.005997             0.75796
# 1005                           0.000000             0.75597
# 1006                           0.000000             0.75605
# 1007                           0.008094             0.76145
#
#       discrimination_relab_0.2  discrimination_relab_abs_0.2  \
# 0                      0.01448                       0.01448
# 1                      0.01214                       0.01214
# 2                      0.01458                       0.01458
# 3                      0.01158                       0.01158
# 4                      0.01219                       0.01219
# ...                        ...                           ...
# 1003                  -0.00054                       0.00053
# 1004                  -0.00022                       0.00021
# 1005                   0.00000                       0.00000
# 1006                   0.00000                       0.00000
# 1007                   0.00025                       0.00025
#
#       accuracy_relab_test_0.2  discrimination_relab_test_0.2  \
# 0                     0.76261                       0.005957
# 1                     0.75796                       0.015371
# 2                     0.77722                       0.005601
# 3                     0.76427                       0.017517
# 4                     0.75697                       0.015000
# ...                       ...                            ...
# 1003                  0.75132                      -0.004888
# 1004                  0.76062                      -0.005997
# 1005                  0.74767                       0.000000
# 1006                  0.74734                       0.000000
# 1007                  0.74667                      -0.008094
#
#       discrimination_relab_test_abs_0.2  accuracy_relab_0.3  \
# 0                              0.005957             0.76294
# 1                              0.015371             0.76411
# 2                              0.005601             0.75929
# 3                              0.017517             0.76253
# 4                              0.015000             0.76435
# ...                                 ...                 ...
# 1003                           0.004888             0.76029
# 1004                           0.005997             0.75796
# 1005                           0.000000             0.75597
# 1006                           0.000000             0.75605
# 1007                           0.008094             0.76145
#
#       discrimination_relab_0.3  discrimination_relab_abs_0.3  \
# 0                      0.01448                       0.01448
# 1                      0.01214                       0.01214
# 2                      0.01458                       0.01458
# 3                      0.01158                       0.01158
# 4                      0.01219                       0.01219
# ...                        ...                           ...
# 1003                  -0.00054                       0.00053
# 1004                  -0.00022                       0.00021
# 1005                   0.00000                       0.00000
# 1006                   0.00000                       0.00000
# 1007                   0.00025                       0.00025
#
#       accuracy_relab_test_0.3  discrimination_relab_test_0.3  \
# 0                     0.76261                       0.005957
# 1                     0.75796                       0.015371
# 2                     0.77722                       0.005601
# 3                     0.76427                       0.017517
# 4                     0.75697                       0.015000
# ...                       ...                            ...
# 1003                  0.75132                      -0.004888
# 1004                  0.76062                      -0.005997
# 1005                  0.74767                       0.000000
# 1006                  0.74734                       0.000000
# 1007                  0.74667                      -0.008094
#
#       discrimination_relab_test_abs_0.3
# 0                              0.005957
# 1                              0.015371
# 2                              0.005601
# 3                              0.017517
# 4                              0.015000
# ...                                 ...
# 1003                           0.004888
# 1004                           0.005997
# 1005                           0.000000
# 1006                           0.000000
# 1007                           0.008094
#
# [1008 rows x 62 columns]

# %%
df_pydl2
# Out:
#            k  depth  random_state   clf.error_  clf.accuracy_  accuracy_pred  \
# 0          0      1             2  2856.000000       0.762948       0.762948
# 1          0      1             7  2842.000000       0.764110       0.764110
# 2          0      1            12  2900.000000       0.759296       0.759296
# 3          0      1            17  2860.000000       0.762616       0.762533
# 4          0      1            22  2839.000000       0.764359       0.764359
# ...      ...    ...           ...          ...            ...            ...
# 1003  100000      7            77  2941.038086       0.755890       0.760292
# 1004  100000      7            82  2937.699707       0.756167       0.757968
# 1005  100000      7            87  2939.000000       0.756059       0.755976
# 1006  100000      7            92  2938.000000       0.756142       0.756059
# 1007  100000      7            97  2887.530029       0.760331       0.761454
#
#       accuracy_test  sum_misclassified_train  discrimination_train  \
# 0          0.762616                     2856              0.197352
# 1          0.757968                     2842              0.193553
# 2          0.777224                     2900              0.202440
# 3          0.764276                     2861              0.197610
# 4          0.756972                     2839              0.202128
# ...             ...                      ...                   ...
# 1003       0.751328                     2888              0.197487
# 1004       0.760624                     2916              0.198086
# 1005       0.747676                     2940              0.199320
# 1006       0.747344                     2939              0.196619
# 1007       0.746680                     2874              0.193494
#
#       sum_discrimination_additive_train  \
# 0                              0.197352
# 1                              0.193553
# 2                              0.202440
# 3                              0.197610
# 4                              0.202128
# ...                                 ...
# 1003                           0.197487
# 1004                           0.198086
# 1005                           0.199320
# 1006                           0.196619
# 1007                           0.193494
#
#       sum_discrimination_additive_train_abs  discrimination_train_pred  \
# 0                                  0.197352                   0.014486
# 1                                  0.193553                   0.012149
# 2                                  0.202440                   0.014589
# 3                                  0.197610                   0.011584
# 4                                  0.202128                   0.012191
# ...                                     ...                        ...
# 1003                               0.197487                  -0.000530
# 1004                               0.198086                  -0.000217
# 1005                               0.199320                   0.000000
# 1006                               0.196619                   0.000000
# 1007                               0.193494                   0.000259
#
#       sum_discrimination_additive_train_pred  \
# 0                                   0.014486
# 1                                   0.012149
# 2                                   0.014589
# 3                                   0.011584
# 4                                   0.012191
# ...                                      ...
# 1003                               -0.000530
# 1004                               -0.000217
# 1005                                0.000000
# 1006                                0.000000
# 1007                                0.000259
#
#       sum_discrimination_additive_train_pred_abs  discrimination_test  \
# 0                                       0.014486             0.005957
# 1                                       0.012149             0.015371
# 2                                       0.014589             0.005601
# 3                                       0.011584             0.017517
# 4                                       0.012191             0.015000
# ...                                          ...                  ...
# 1003                                    0.000530            -0.004888
# 1004                                    0.000217            -0.005997
# 1005                                    0.000000             0.000000
# 1006                                    0.000000             0.000000
# 1007                                    0.000259            -0.008094
#
#       sum_discrimination_additive_test_pred  \
# 0                                  0.005957
# 1                                  0.015371
# 2                                  0.005601
# 3                                  0.017517
# 4                                  0.015000
# ...                                     ...
# 1003                              -0.004888
# 1004                              -0.005997
# 1005                               0.000000
# 1006                               0.000000
# 1007                              -0.008094
#
#       sum_discrimination_additive_test_pred_abs    duration  min_supp  \
# 0                                      0.005957    0.303321         2
# 1                                      0.015371    0.495664         2
# 2                                      0.005601    0.464104         2
# 3                                      0.017517    0.574968         2
# 4                                      0.015000    0.452100         2
# ...                                         ...         ...       ...
# 1003                                   0.004888  300.732979         2
# 1004                                   0.005997  300.871734         2
# 1005                                   0.000000  300.830105         2
# 1006                                   0.000000  300.788495         2
# 1007                                   0.008094  300.729402         2
#
#                                               clf.tree_
# 0     {'feat': 19, 'left': {'value': 1, 'error': 43....
# 1     {'feat': 19, 'left': {'value': 1, 'error': 44....
# 2     {'feat': 19, 'left': {'value': 1, 'error': 46....
# 3     {'feat': 19, 'left': {'value': 1, 'error': 48....
# 4     {'feat': 19, 'left': {'value': 1, 'error': 43....
# ...                                                 ...
# 1003  {'feat': 17, 'left': {'value': 1, 'error': 379...
# 1004  {'feat': 17, 'left': {'value': 1, 'error': 371...
# 1005  {'feat': 38, 'left': {'value': 0, 'error': 105...
# 1006  {'feat': 36, 'left': {'value': 0, 'error': 77....
# 1007  {'feat': 17, 'left': {'value': 1, 'error': 328...
#
# [1008 rows x 20 columns]

# %%
df_sklearn
# Out:
#      k  depth  random_state  accuracy_pred  accuracy_test  \
# 0    0      1             2       0.753652       0.756972
# 1    0      2             2       0.784695       0.789841
# 2    0      3             2       0.803453       0.807769
# 3    0      4             2       0.820219       0.822377
# 4    0      5             2       0.821132       0.822045
# ..  ..    ...           ...            ...            ...
# 121  0      3            97       0.804366       0.798805
# 122  0      4            97       0.817397       0.810093
# 123  0      5            97       0.825033       0.815737
# 124  0      6            97       0.829100       0.816401
# 125  0      7            97       0.832586       0.817729
#
#      discrimination_train  discrimination_train_pred  discrimination_test  \
# 0                0.197352                   0.000000             0.000000
# 1                0.197352                   0.081071             0.091054
# 2                0.197352                   0.120383             0.122872
# 3                0.197352                   0.171466             0.161662
# 4                0.197352                   0.167770             0.163660
# ..                    ...                        ...                  ...
# 121              0.193494                   0.108137             0.130924
# 122              0.193494                   0.136872             0.151280
# 123              0.193494                   0.173121             0.179702
# 124              0.193494                   0.156140             0.163853
# 125              0.193494                   0.158455             0.166638
#
#      sum_discrimination_additive_train  \
# 0                             0.197352
# 1                             0.197352
# 2                             0.197352
# 3                             0.197352
# 4                             0.197352
# ..                                 ...
# 121                           0.193494
# 122                           0.193494
# 123                           0.193494
# 124                           0.193494
# 125                           0.193494
#
#      sum_discrimination_additive_train_pred  \
# 0                                  0.000000
# 1                                  0.081071
# 2                                  0.120383
# 3                                  0.171466
# 4                                  0.167770
# ..                                      ...
# 121                                0.108137
# 122                                0.136872
# 123                                0.173121
# 124                                0.156140
# 125                                0.158455
#
#      sum_discrimination_additive_test_pred  \
# 0                                 0.000000
# 1                                 0.091054
# 2                                 0.122872
# 3                                 0.161662
# 4                                 0.163660
# ..                                     ...
# 121                               0.130924
# 122                               0.151280
# 123                               0.179702
# 124                               0.163853
# 125                               0.166638
#
#      sum_discrimination_additive_train_abs  \
# 0                                 0.224403
# 1                                 0.224403
# 2                                 0.226721
# 3                                 0.230081
# 4                                 0.231085
# ..                                     ...
# 121                               0.222677
# 122                               0.225882
# 123                               0.226128
# 124                               0.228684
# 125                               0.230178
#
#      sum_discrimination_additive_train_pred_abs  \
# 0                                      0.000000
# 1                                      0.081071
# 2                                      0.120383
# 3                                      0.171997
# 4                                      0.174273
# ..                                          ...
# 121                                    0.108137
# 122                                    0.137732
# 123                                    0.173719
# 124                                    0.159324
# 125                                    0.163395
#
#      sum_discrimination_additive_test_pred_abs  min_supp  \
# 0                                     0.000000         2
# 1                                     0.091054         2
# 2                                     0.137832         2
# 3                                     0.187596         2
# 4                                     0.182611         2
# ..                                         ...       ...
# 121                                   0.130924         2
# 122                                   0.163725         2
# 123                                   0.184861         2
# 124                                   0.169011         2
# 125                                   0.173844         2
#
#                                              clf.tree_  accuracy_relab_1  \
# 0    <sklearn.tree._tree.Tree object at 0x7f26ac156...            0.2883
# 1    <sklearn.tree._tree.Tree object at 0x7f26ac156...            0.7730
# 2    <sklearn.tree._tree.Tree object at 0x7f26ac156...            0.8024
# 3    <sklearn.tree._tree.Tree object at 0x7f26ac156...            0.8190
# 4    <sklearn.tree._tree.Tree object at 0x7f26ac156...            0.8211
# ..                                                 ...               ...
# 121  <sklearn.tree._tree.Tree object at 0x7f26ab38a...            0.8044
# 122  <sklearn.tree._tree.Tree object at 0x7f26ab38a...            0.8168
# 123  <sklearn.tree._tree.Tree object at 0x7f26ab38a...            0.8250
# 124  <sklearn.tree._tree.Tree object at 0x7f26ab38a...            0.8288
# 125  <sklearn.tree._tree.Tree object at 0x7f26ab38a...            0.8326
#
#      discrimination_relab_1  discrimination_relab_abs_1  \
# 0                 -0.464622                    0.464622
# 1                  0.049883                    0.112258
# 2                  0.113298                    0.127468
# 3                  0.164646                    0.178817
# 4                  0.167258                    0.174785
# ..                      ...                         ...
# 121                0.106855                    0.109419
# 122                0.129630                    0.144973
# 123                0.172990                    0.173850
# 124                0.150692                    0.164772
# 125                0.157947                    0.163904
#
#      accuracy_relab_test_1  discrimination_relab_test_1  \
# 0                   0.2942                    -0.478631
# 1                   0.7739                     0.058128
# 2                   0.8071                     0.115390
# 3                   0.8217                     0.154179
# 4                   0.8220                     0.163660
# ..                     ...                          ...
# 121                 0.7995                     0.129778
# 122                 0.8084                     0.143502
# 123                 0.8157                     0.179702
# 124                 0.8151                     0.157630
# 125                 0.8177                     0.166638
#
#      discrimination_relab_test_abs_1  accuracy_relab_2  \
# 0                           0.478631            0.2883
# 1                           0.123981            0.7419
# 2                           0.145315            0.7705
# 3                           0.195079            0.8044
# 4                           0.182611            0.8211
# ..                               ...               ...
# 121                         0.132070            0.8035
# 122                         0.171504            0.8167
# 123                         0.184861            0.8249
# 124                         0.175234            0.8281
# 125                         0.173844            0.8325
#
#      discrimination_relab_2  discrimination_relab_abs_2  \
# 0                 -0.464622                    0.464622
# 1                 -0.031187                    0.031187
# 2                  0.032679                    0.046849
# 3                  0.110524                    0.124695
# 4                  0.167125                    0.174918
# ..                      ...                         ...
# 121                0.099606                    0.116668
# 122                0.129127                    0.144470
# 123                0.167411                    0.179429
# 124                0.145605                    0.159685
# 125                0.155997                    0.161954
#
#      accuracy_relab_test_2  discrimination_relab_test_2  \
# 0                   0.2942                    -0.478631
# 1                   0.7410                    -0.032927
# 2                   0.7736                     0.025331
# 3                   0.8071                     0.107416
# 4                   0.8220                     0.163660
# ..                     ...                          ...
# 121                 0.7978                     0.122982
# 122                 0.8081                     0.148701
# 123                 0.8141                     0.172456
# 124                 0.8151                     0.152797
# 125                 0.8177                     0.165205
#
#      discrimination_relab_test_abs_2  accuracy_relab_3  \
# 0                           0.478631            0.2883
# 1                           0.032927            0.2883
# 2                           0.055256            0.7599
# 3                           0.148316            0.8043
# 4                           0.182611            0.8152
# ..                               ...               ...
# 121                         0.138865            0.7719
# 122                         0.166305            0.8053
# 123                         0.192107            0.8190
# 124                         0.170401            0.8197
# 125                         0.172410            0.8320
#
#      discrimination_relab_3  discrimination_relab_abs_3  \
# 0                 -0.464622                    0.464622
# 1                 -0.464622                    0.464622
# 2                  0.008577                    0.070951
# 3                  0.109927                    0.124098
# 4                  0.125929                    0.133721
# ..                      ...                         ...
# 121                0.021041                    0.038104
# 122                0.099487                    0.114830
# 123                0.125313                    0.137330
# 124                0.110264                    0.124345
# 125                0.150811                    0.167140
#
#      accuracy_relab_test_3  discrimination_relab_test_3  \
# 0                   0.2942                    -0.478631
# 1                   0.2942                    -0.478631
# 2                   0.7583                    -0.000113
# 3                   0.8068                     0.112904
# 4                   0.8167                     0.130333
# ..                     ...                          ...
# 121                 0.7633                     0.024534
# 122                 0.7968                     0.122572
# 123                 0.8088                     0.142804
# 124                 0.8078                     0.127446
# 125                 0.8164                     0.158982
#
#      discrimination_relab_test_abs_3  accuracy_relab_0.0  \
# 0                           0.478631              0.7537
# 1                           0.478631              0.7419
# 2                           0.080700              0.7423
# 3                           0.142829              0.7426
# 4                           0.149283              0.7599
# ..                               ...                 ...
# 121                         0.040417              0.7615
# 122                         0.140176              0.7566
# 123                         0.162455              0.7653
# 124                         0.145050              0.7624
# 125                         0.178633              0.7644
#
#      discrimination_relab_0.0  discrimination_relab_abs_0.0  \
# 0                    0.000000                      0.000000
# 1                   -0.031187                      0.031187
# 2                   -0.030876                      0.031499
# 3                   -0.030364                      0.032256
# 4                   -0.004739                      0.059150
# ..                        ...                           ...
# 121                 -0.001024                      0.060168
# 122                 -0.013296                      0.040251
# 123                 -0.001990                      0.054851
# 124                 -0.017685                      0.110980
# 125                 -0.018541                      0.111574
#
#      accuracy_relab_test_0.0  discrimination_relab_test_0.0  \
# 0                     0.7570                       0.000000
# 1                     0.7410                      -0.032927
# 2                     0.7404                      -0.040406
# 3                     0.7404                      -0.040406
# 4                     0.7550                      -0.016024
# ..                       ...                            ...
# 121                   0.7473                      -0.009240
# 122                   0.7407                      -0.026279
# 123                   0.7490                      -0.009487
# 124                   0.7437                      -0.029377
# 125                   0.7420                      -0.030319
#
#      discrimination_relab_test_abs_0.0  accuracy_relab_0.1  \
# 0                             0.000000              0.7537
# 1                             0.032927              0.7847
# 2                             0.040406              0.7705
# 3                             0.040406              0.7854
# 4                             0.064789              0.7920
# ..                                 ...                 ...
# 121                           0.074191              0.8035
# 122                           0.051587              0.8053
# 123                           0.071490              0.7814
# 124                           0.120538              0.8040
# 125                           0.117549              0.8111
#
#      discrimination_relab_0.1  discrimination_relab_abs_0.1  \
# 0                    0.000000                      0.000000
# 1                    0.081071                      0.081071
# 2                    0.032679                      0.046849
# 3                    0.056962                      0.071132
# 4                    0.060598                      0.076549
# ..                        ...                           ...
# 121                  0.099606                      0.116668
# 122                  0.099487                      0.114830
# 123                  0.030148                      0.048540
# 124                  0.073112                      0.160510
# 125                  0.077754                      0.102984
#
#      accuracy_relab_test_0.1  discrimination_relab_test_0.1  \
# 0                     0.7570                       0.000000
# 1                     0.7898                       0.091054
# 2                     0.7736                       0.025331
# 3                     0.7849                       0.052201
# 4                     0.7908                       0.050709
# ..                       ...                            ...
# 121                   0.7978                       0.122982
# 122                   0.7968                       0.122572
# 123                   0.7709                       0.030309
# 124                   0.7932                       0.094491
# 125                   0.7955                       0.093333
#
#      discrimination_relab_test_abs_0.1  accuracy_relab_0.2  \
# 0                             0.000000              0.7537
# 1                             0.091054              0.7847
# 2                             0.055256              0.8035
# 3                             0.082126              0.8202
# 4                             0.080634              0.8211
# ..                                 ...                 ...
# 121                           0.138865              0.8044
# 122                           0.140176              0.8174
# 123                           0.051024              0.8250
# 124                           0.178004              0.8291
# 125                           0.116095              0.8326
#
#      discrimination_relab_0.2  discrimination_relab_abs_0.2  \
# 0                    0.000000                      0.000000
# 1                    0.081071                      0.081071
# 2                    0.120383                      0.120383
# 3                    0.171466                      0.171997
# 4                    0.167770                      0.174273
# ..                        ...                           ...
# 121                  0.108137                      0.108137
# 122                  0.136872                      0.137732
# 123                  0.173121                      0.173719
# 124                  0.156140                      0.159324
# 125                  0.158455                      0.163395
#
#      accuracy_relab_test_0.2  discrimination_relab_test_0.2  \
# 0                     0.7570                       0.000000
# 1                     0.7898                       0.091054
# 2                     0.8078                       0.122872
# 3                     0.8224                       0.161662
# 4                     0.8220                       0.163660
# ..                       ...                            ...
# 121                   0.7988                       0.130924
# 122                   0.8101                       0.151280
# 123                   0.8157                       0.179702
# 124                   0.8164                       0.163853
# 125                   0.8177                       0.166638
#
#      discrimination_relab_test_abs_0.2  accuracy_relab_0.3  \
# 0                             0.000000              0.7537
# 1                             0.091054              0.7847
# 2                             0.137832              0.8035
# 3                             0.187596              0.8202
# 4                             0.182611              0.8211
# ..                                 ...                 ...
# 121                           0.130924              0.8044
# 122                           0.163725              0.8174
# 123                           0.184861              0.8250
# 124                           0.169011              0.8291
# 125                           0.173844              0.8326
#
#      discrimination_relab_0.3  discrimination_relab_abs_0.3  \
# 0                    0.000000                      0.000000
# 1                    0.081071                      0.081071
# 2                    0.120383                      0.120383
# 3                    0.171466                      0.171997
# 4                    0.167770                      0.174273
# ..                        ...                           ...
# 121                  0.108137                      0.108137
# 122                  0.136872                      0.137732
# 123                  0.173121                      0.173719
# 124                  0.156140                      0.159324
# 125                  0.158455                      0.163395
#
#      accuracy_relab_test_0.3  discrimination_relab_test_0.3  \
# 0                     0.7570                       0.000000
# 1                     0.7898                       0.091054
# 2                     0.8078                       0.122872
# 3                     0.8224                       0.161662
# 4                     0.8220                       0.163660
# ..                       ...                            ...
# 121                   0.7988                       0.130924
# 122                   0.8101                       0.151280
# 123                   0.8157                       0.179702
# 124                   0.8164                       0.163853
# 125                   0.8177                       0.166638
#
#      discrimination_relab_test_abs_0.3
# 0                             0.000000
# 1                             0.091054
# 2                             0.137832
# 3                             0.187596
# 4                             0.182611
# ..                                 ...
# 121                           0.130924
# 122                           0.163725
# 123                           0.184861
# 124                           0.169011
# 125                           0.173844
#
# [126 rows x 58 columns]

# %%
list_k = df_pydl["k"].unique()
list_k = [0, 1000, 2000, 3000, 4000, 5000, 10000, 100000]

# %%
_COLORS4 = ['#ff0000', '#00ff00', '#0000ff', '#87cefa']
_COLORS5 = ['#008080', '#ffa500', '#00ff00', '#0000ff', '#ff1493']
_COLORS7 = ['#2e8b57', '#ff0000', '#ffd700', '#c71585', '#00ff00', '#0000ff', '#1e90ff']
_COLORS10 = ['#006400', '#00008b', '#b03060', '#ff4500', '#ffd700', '#7cfc00', '#00ffff', '#ff00ff', '#6495ed',
          '#ffdab9']
_COLORS11 = ['#8b4513', '#006400', '#4682b4', '#4b0082', '#ff0000', '#ffff00', '#00ff7f', '#00ffff', '#ff00ff', '#ffff54',
             '#ffe4c4']

# %%
def graphh(axe1, axe2, x_size, y_size):
    colors11 = _COLORS11.copy()
    colors5 = _COLORS11.copy()
    colors4 = _COLORS5.copy()
    legends = ['< 0', '< 0.1', '< 0.2', '< 0.3', 'no relab']
    fig, axes = plt.subplots()

    for depth in df_sklearn['depth'].unique():
        index_legends = 0
        y_values = list()
        x_values = list()
        y_values_pydl = list()
        x_values_pydl = list()
        for x_axe, y_axe in axe1:

            tmp = df_sklearn.loc[(df_sklearn["k"] == 0) & (df_sklearn["depth"] == depth)]
            x_values.append(tmp[x_axe].mean())
            y_values.append(tmp[y_axe].mean())

            if index_legends == 0:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors5[index_legends], marker='x')
            else:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors5[index_legends])

            tmp = df_pydl.loc[(df_pydl["k"] == 0) & (df_pydl["depth"] == depth)]
            x_values_pydl.append(tmp[x_axe].mean())
            y_values_pydl.append(tmp[y_axe].mean())

            if index_legends == 0:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors5[index_legends], marker='x')
            else:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors5[index_legends])

            index_legends +=1
        plt.plot(x_values, y_values, label="Sklearn (relab)", c=colors4[0])
        plt.plot(x_values_pydl, y_values_pydl, label="Pydl (relab)", c=colors4[1])

        """
        y_values = list()
        x_values = list()
        x_axe = axe2[0]
        y_axe = axe2[1]
        index_legends = 0
        #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
        for k in [0, 5, 10, 100, 500, 1000, 5000]:
            tmp = df_pydl.loc[(df_pydl["k"] == k) & (df_pydl["depth"] == depth)]
            x_values.append(tmp[x_axe].mean())
            y_values.append(tmp[y_axe].mean())

            if index_legends == 0:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends], marker='x')
            else:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends])

            index_legends +=1

        plt.plot(x_values, y_values, label="Pydl (constantes)", c=colors4[2])
        """
        # PYDL 2
        y_values = list()
        x_values = list()
        x_axe = axe2[0]
        y_axe = axe2[1]
        index_legends = 0
        #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
        for k in list_k:
            tmp = df_pydl2.loc[(df_pydl2["k"] == k) & (df_pydl2["depth"] == depth)]
            x_values.append(tmp[x_axe].mean())
            y_values.append(tmp[y_axe].mean())

            if index_legends == 0:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends], marker='x')
            else:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends])

            index_legends +=1

        plt.plot(x_values, y_values, label="Pydl (constantes2)", c=colors4[3])

        """
        # PYDL 3
        y_values = list()
        x_values = list()
        x_axe = axe2[0]
        y_axe = axe2[1]
        index_legends = 0
        #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
        for k in [0, 5, 10, 100, 500, 1000, 5000]:
            tmp = df_pydl3.loc[(df_pydl3["k"] == k) & (df_pydl3["depth"] == depth)]
            x_values.append(tmp[x_axe].mean())
            y_values.append(tmp[y_axe].mean())

            if index_legends == 0:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends], marker='x')
            else:
                plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends])

            index_legends +=1

        plt.plot(x_values, y_values, label="Pydl (constantes3)", c=colors4[4])
        """
        
        plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
        plt.title(f'Depth {depth}')
        plt.ylabel('discrimination')
        plt.xlabel('accuracy')
        plt.ylim(y_size[0], y_size[1])
        plt.xlim(x_size[0], x_size[1])
        plt.legend()

        plt.show()

# %% [markdown]
# # Train

# %% [markdown]
# ## Threshold

# %% [markdown]
# ### Train. Threshold

# %%
graphh([('accuracy_pred', 'discrimination_train_pred'), ('accuracy_relab_0.3', 'discrimination_relab_0.3'), ('accuracy_relab_0.2', 'discrimination_relab_0.2'), ('accuracy_relab_0.1', 'discrimination_relab_0.1'), ('accuracy_relab_0.0', 'discrimination_relab_0.0')], ("accuracy_pred", "sum_discrimination_additive_train_pred"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# ### Train. Threshold Absolute

# %%
graphh([('accuracy_pred', 'sum_discrimination_additive_train_pred_abs'), ('accuracy_relab_0.3', 'discrimination_relab_abs_0.3'), ('accuracy_relab_0.2', 'discrimination_relab_abs_0.2'), ('accuracy_relab_0.1', 'discrimination_relab_abs_0.1'),('accuracy_relab_0.0', 'discrimination_relab_abs_0.0')], ("accuracy_pred", "sum_discrimination_additive_train_pred_abs"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# ## Leaf

# %% [markdown]
# ### Train. Leaf

# %%
graphh([('accuracy_pred', 'discrimination_train_pred'), ('accuracy_relab_1', 'discrimination_relab_1'), ('accuracy_relab_2', 'discrimination_relab_2'), ('accuracy_relab_3', 'discrimination_relab_3')], ("accuracy_pred", "discrimination_train_pred"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# ### Train. Leaf Absolute

# %%
graphh([('accuracy_pred', 'sum_discrimination_additive_train_pred_abs'), ('accuracy_relab_1', 'discrimination_relab_abs_1'), ('accuracy_relab_2', 'discrimination_relab_abs_2'), ('accuracy_relab_3', 'discrimination_relab_abs_3')], ("accuracy_pred", "sum_discrimination_additive_train_pred_abs"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# # Test

# %% [markdown]
# ## Threshold

# %% [markdown]
# ### Test. Threshold

# %%
graphh([('accuracy_test', 'discrimination_test'), ('accuracy_relab_test_0.3', 'discrimination_relab_test_0.3'), ('accuracy_relab_test_0.2', 'discrimination_relab_test_0.2'), ('accuracy_relab_test_0.1', 'discrimination_relab_test_0.1'), ('accuracy_relab_test_0.0', 'discrimination_relab_test_0.0'), ], ("accuracy_test", "discrimination_test"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# ### Test. Threshold Absolute

# %%
graphh([('accuracy_test', 'sum_discrimination_additive_test_pred_abs'), ('accuracy_relab_test_0.3', 'discrimination_relab_test_abs_0.3'), ('accuracy_relab_test_0.2', 'discrimination_relab_test_abs_0.2'), ('accuracy_relab_test_0.1', 'discrimination_relab_test_abs_0.1'), ('accuracy_relab_test_0.0', 'discrimination_relab_test_abs_0.0')], ("accuracy_test", "sum_discrimination_additive_test_pred_abs"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# ## Leaf

# %% [markdown]
# ### Test. Leaf

# %%
graphh([('accuracy_test', 'discrimination_test'), ('accuracy_relab_test_1', 'discrimination_relab_test_1'), ('accuracy_relab_test_2', 'discrimination_relab_test_2'), ('accuracy_relab_test_3', 'discrimination_relab_test_3')], ("accuracy_test", "discrimination_test"), (0, 1), (-0.2, 0.8))

# %% [markdown]
# ### Test. Leaf Absolute

# %%
graphh([('accuracy_test', 'sum_discrimination_additive_test_pred_abs'), ('accuracy_relab_test_1', 'discrimination_relab_test_abs_1'), ('accuracy_relab_test_2', 'discrimination_relab_test_abs_2'), ('accuracy_relab_test_3', 'discrimination_relab_test_abs_3')], ("accuracy_test", "sum_discrimination_additive_test_pred_abs"), (0, 1), (-0.2, 0.8))

# %%
colors11 = _COLORS11.copy()
colors5 = _COLORS11.copy()
colors4 = _COLORS5.copy()
legends = ['< 0', '< 0.1', '< 0.2', '< 0.3', 'no relab']
fig, axes = plt.subplots()

for depth in df_sklearn['depth'].unique():
    index_legends = 0
    y_values = list()
    x_values = list()
    y_values_pydl = list()
    x_values_pydl = list()
    axe2 = ("accuracy_pred", "sum_discrimination_additive_train_pred")
    x_axe = axe2[0]
    y_axe = axe2[1]
    index_legends = 0
    #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
    for k in list_k:
        tmp = df_pydl2.loc[(df_pydl2["k"] == k) & (df_pydl2["depth"] == depth)]
        x_values.append(tmp[x_axe].mean())
        y_values.append(tmp[y_axe].mean())

        if index_legends == 0:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends], marker='x')
        else:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends])

        index_legends +=1

    plt.plot(x_values, y_values, label="Pydl (DATC)", c=colors4[2])

    # PYDL 2
    y_values = list()
    x_values = list()

    axe2 = ("accuracy_pred", "sum_discrimination_additive_train_pred_abs")
    x_axe = axe2[0]
    y_axe = axe2[1]
    index_legends = 0
    #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
    for k in list_k:
        tmp = df_pydl2.loc[(df_pydl2["k"] == k) & (df_pydl2["depth"] == depth)]
        x_values.append(tmp[x_axe].mean())
        y_values.append(tmp[y_axe].mean())

        if index_legends == 0:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends], marker='x')
        else:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends])

        index_legends +=1

    plt.plot(x_values, y_values, label="Pydl (DATC abs)", c=colors4[3])


    plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
    plt.title(f'Depth {depth}')
    plt.ylabel('discrimination')
    plt.xlabel('accuracy')
    plt.legend()

    plt.show()

# %%
colors11 = _COLORS11.copy()
colors5 = _COLORS11.copy()
colors4 = _COLORS5.copy()
legends = ['< 0', '< 0.1', '< 0.2', '< 0.3', 'no relab']
fig, axes = plt.subplots()

for depth in df_sklearn['depth'].unique():
    index_legends = 0
    y_values = list()
    x_values = list()
    y_values_pydl = list()
    x_values_pydl = list()
    axe2 = ("accuracy_pred", "sum_discrimination_additive_train_pred")
    x_axe = axe2[0]
    y_axe = axe2[1]
    index_legends = 0
    #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
    for k in list_k:
        tmp = df_pydl.loc[(df_pydl["k"] == k) & (df_pydl["depth"] == depth)]
        x_values.append(tmp[x_axe].mean())
        y_values.append(tmp[y_axe].mean())

        if index_legends == 0:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends], marker='x')
        else:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends])

        index_legends +=1

    plt.plot(x_values, y_values, label="Pydl (relab)", c=colors4[2])

    # PYDL 2
    y_values = list()
    x_values = list()

    axe2 = ("accuracy_pred", "sum_discrimination_additive_train_pred_abs")
    x_axe = axe2[0]
    y_axe = axe2[1]
    index_legends = 0
    #for k in [0, 1, 5, 10, 50, 100, 250, 500, 1000, 5000, 100000]:
    for k in list_k:
        tmp = df_pydl.loc[(df_pydl["k"] == k) & (df_pydl["depth"] == depth)]
        x_values.append(tmp[x_axe].mean())
        y_values.append(tmp[y_axe].mean())

        if index_legends == 0:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends], marker='x')
        else:
            plt.scatter(tmp[x_axe].mean(), tmp[y_axe].mean(), c=colors11[index_legends])

        index_legends +=1

    plt.plot(x_values, y_values, label="Pydl (relab abs)", c=colors4[3])


    plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
    plt.title(f'Depth {depth}')
    plt.ylabel('discrimination')
    plt.xlabel('accuracy')
    plt.legend()

    plt.show()
